# %%
# Imports

import os
import datetime
from pathlib import Path
import pandas as pd
import json
import requests
import urllib.parse
import numpy as np

# %% [markdown]
# # Setup

# %%
# Get absolute path
absPath = str(Path(os.path.abspath(os.getcwd())).absolute())
datasetsPath = os.path.join(absPath, "datasets")

# Create dataset directory if not exists
if not os.path.exists(datasetsPath):
    os.mkdir(datasetsPath)

# Setup datasets paths
artistsPath = os.path.join(datasetsPath, "artists.csv")
peoplePath = os.path.join(datasetsPath, "people.csv")

# %% [markdown]
# # WikiData API Functions

# %% [markdown]
# https://www.wikidata.org/w/api.php

# %%
# Query to WikiData to get a list of search results. Ideally the first result should be the one we are looking for
def wdQuery(query):
    # Format the request (encoding the query text)
    queryApiRequest = requests.get(
        "https://www.wikidata.org/w/api.php?action=query&format=json&list=search&srsearch={q}&srlimit=20".format(q=urllib.parse.quote_plus(query)))
    
    # If there is a response, then return the json
    if queryApiRequest.status_code == 200:
        return json.loads(queryApiRequest.text)
    
    return None

# Query to WikiData to get the entity information from the ID retrieved from the query results
def wdGetEntity(entityID):
    # Format the request
    queryApiRequest = requests.get(
        "https://www.wikidata.org/w/api.php?action=wbgetentities&ids={eID}&format=json".format(eID=entityID))

    # If there is a response, then return the json
    if queryApiRequest.status_code == 200:
        return json.loads(queryApiRequest.text)["entities"][entityID]

    return None

def wdGetProperty(entityID, propertyID):
    # Format the request
    queryApiRequest = requests.get(
        "https://www.wikidata.org/w/api.php?action=wbgetclaims&entity={eID}&property={pID}&format=json".format(eID=entityID, pID=propertyID))

    # If there is a valid response, then return the json
    if queryApiRequest.status_code == 200:
        try:
            return json.loads(queryApiRequest.text)["claims"][propertyID]
        except:
            return None

    return None

# %% [markdown]
# # MusicBrainz API Functions

# %% [markdown]
# https://musicbrainz.org/doc/MusicBrainz_API

# %%
def mbQuery(query):
    # Format the request (encoding the query text)
    queryApiRequest = requests.get(
        "https://musicbrainz.org/ws/2/artist?query={q}&limit=20&fmt=json".format(q=urllib.parse.quote_plus(query.lower().removeprefix("the "))))

    # If there is a response, then return the json
    if queryApiRequest.status_code == 200:
        return json.loads(queryApiRequest.text)
    
    return None

# Get the artist information. From MusicBrainz API, using includes can
# be retrieved also other information, like aliases, urls, artists relationships etc.
# By default mbGetArtist uses aliases and url-rels. For artists (like members of group)
# can be used artist-rels. Other type in the API documentation.
def mbGetArtist(artistID, includes=None):
    includesStr = "+" + "+".join(includes) if not includes is None and len(includes) > 0 else ""
    # Format the request
    queryApiRequest = requests.get(
        "https://musicbrainz.org/ws/2/artist/{artistID}?fmt=json&inc=aliases+url-rels{incs}".format(artistID=artistID, incs=includesStr))

    # If there is a response, then return the json
    if queryApiRequest.status_code == 200:
        return json.loads(queryApiRequest.text)

    return None

# %% [markdown]
# # Data Retrieval

# %% [markdown]
# ## Utilities

# %% [markdown]
# ### Constants Utilities

# %%
# Map the properties and the entities codes with a human-friendly name
WD_MAP = {
    "instanceOf": "P31",
    "name": "P735",
    "birthName": "P1477",
    "surname": "P734",
    "birthDate": "P569",
    "deathDate": "P570",
    "country": "P27",
    "countryISOCode": "P297",
    "hasPart": "P527",
    "human": "Q5",
    "nativeName": "P1705",
    "musicalGroup": "Q215380"
}

# Set the types of the retrieved data, this will be used next to get the values from the properties
# externalArrayString is an array of strings that WikiData treats as external entities
# externalString is a string that WikiData treats as external entities
# inValue is a string contained in "targetProperty" field
# date is a date contained in the datavalue field
# country is an external property of the entity
WD_DATA_TYPE = {
    "name": {"type": "externalArrayString"},
    "birthName": {"type": "inValue", "targetProperty": "text"},
    "surname": {"type": "externalArrayString"},
    "birthDate": {"type": "date"},
    "deathDate": {"type": "date"},
    "country": {"type": "externalProperty", "targetProperty": WD_MAP["countryISOCode"]},
}

# The properties to be retrieved for persons or groups
HUMAN_KEYS = ["name", "surname", "birthName", "birthDate", "deathDate", "country"]
GROUP_KEYS = ["hasPart"]

# %% [markdown]
# ### General Utilities

# %%
# Function to get a subset of properties from a WikiData entity
def getSubsetOfKeys(dictObject, keys):
    resultObject = {}

    for key in keys:
        # If there is the property, then add it, otherwise add a null value
        # The new dictionary will have instead of WikiData key property, the one in the WD_MAP
        if WD_MAP[key] in dictObject.keys():
            resultObject[key] = dictObject[WD_MAP[key]]
        else:
            resultObject[key] = None

    return resultObject

# Convert WikiData date into a datetime formatted as Y-m-d
def getDateFromInformation(dateTime, datePrecision):
    # WikiData put 00 in the field month or day for not precise dates
    # This will raise an exception because is a malformed datetime
    dateFormats = ["+%Y-%m-%dT%H:%M:%SZ", "+%Y-%m-00T%H:%M:%SZ", "+%Y-00-00T00:00:00Z"]
    destinationFormats = {"year": "%Y", "month": "%Y-%m", "day": "%Y-%m-%d"}

    destinationFormat = destinationFormats["day"]
    if datePrecision == 10:
        destinationFormat = destinationFormats["month"]
    elif datePrecision <= 9:
        destinationFormat = destinationFormats["year"]

    for dateFormat in dateFormats:
        try:
            return datetime.datetime.strptime(
                dateTime, dateFormat
            ).strftime(destinationFormat)
        except:
            pass
    
    return None

# %% [markdown]
# ### WikiData Entity Utilites

# %%
# WikiData is structured as
# claims --> property --> {0,1,...} --> mainsnak --> datavalue --> value
# This function will return an array of only values (or a single value)
def getDataValue(dictObject, keyProperty=None, expectArray=False):
    arrValues = []
    
    # Check if the property exists in the WikiData entity
    dictPropObject = dictObject if keyProperty is None else dictObject[keyProperty]

    if dictPropObject is None:
        return None

    for keyValue in dictPropObject:
        # If there is a property with no value, datavalue is not present
        if "datavalue" in keyValue["mainsnak"].keys():
            valueToAppend = keyValue["mainsnak"]["datavalue"]["value"]
            arrValues.append(valueToAppend)
    
    # If there are no values return a null object
    if len(arrValues) <= 0:
        return None

    # If an array is expected return an array, otherwise return only the first value
    return arrValues[0] if not expectArray else arrValues

# Get the title of the entity
def getEntityTitle(entity):
    try:
        # If there is the english version of the entity, get it
        return entity["labels"]["en"]["value"]
    except:
        # Otherwise select the first one version
        return entity["labels"][list(entity["labels"])[0]]["value"]

# %% [markdown]
# ### MusicBrainz Utilites

# %%
# MusicBrainz return a list of relations. Often there is a wikidata link
# that connect the artist to its WikiData page
def getMBWikiDataEntityID(artistInformation):
    # If there are relations, check until it finds the wikidata one, and extract the entity ID from the link
    try:
        for artistRelation in artistInformation["relations"]:
            if artistRelation["type"] == "wikidata":
                return artistRelation["url"]["resource"].removeprefix("https://www.wikidata.org/wiki/").strip()
    except:
        pass
    
    # Otherwise return null
    return None

# MusicBrainz return a list of relations. If it is a group, a list of members often is retrieved
def getMBGroupMembers(artistInformation, downloadMembers=False):
    # If there are relations, check until it finds the wikidata one, and extract the entity ID from the link
    groupMembers = []

    if not artistInformation is None and downloadMembers:
        artistInformation = mbGetArtist(artistInformation["id"], includes=["artist-rels"])

    # If there are no relations, then return null
    if artistInformation is None or not "relations" in artistInformation.keys():
        return None
    
    # Check all the relations
    for artistRelation in artistInformation["relations"]:
        try:
            # If the relation is of type "member of band", try get the information of the artist
            if artistRelation["type"] == "member of band" and artistRelation["direction"] == "backward":
                getMemberInformation = mbGetArtist(artistRelation["artist"]["id"])
                groupMembers.append(getMemberInformation)
        except:
            pass

    # Otherwise return null
    return groupMembers

# %% [markdown]
# ### Artist Retrieved Data Utilities

# %%
# Get data from a "human" WikiData entity
def getArtistInformation(entityClaims):
    # Get only the intersted properties
    artistInformation = getSubsetOfKeys(entityClaims, HUMAN_KEYS)
    artistExtractedInformation = {}

    # For each property, check the type in WD_DATA_TYPE and act differently
    for keyValue in artistInformation:
        # Get the data value, as an object or as an array, depending on the data type
        expectArray = WD_DATA_TYPE[keyValue]["type"] == "externalArrayString"
        currentInformation = getDataValue(artistInformation, keyValue, expectArray=expectArray)

        realValue = None
        if not currentInformation is None:
            # Get information about the datatype
            wdDataInformation = WD_DATA_TYPE[keyValue]

            # The data is the name of an external entity
            if wdDataInformation["type"] == "externalString":
                realValue = getEntityTitle(wdGetEntity(currentInformation["id"]))
            
            # The data is an array of names of an array of external entities
            elif wdDataInformation["type"] == "externalArrayString":
                for currentEntityInformation in currentInformation:
                    entityToAppend = getEntityTitle(wdGetEntity(currentEntityInformation["id"]))
                    
                    if realValue is None and not entityToAppend is None:
                        realValue = []

                    if not entityToAppend is None:
                        realValue.append(entityToAppend)
            
            # The data is a property of an external WikiData entity
            elif wdDataInformation["type"] == "externalProperty":
                realValue = getDataValue(wdGetProperty(
                    entityID=currentInformation["id"],
                    propertyID=wdDataInformation["targetProperty"]
                ))
                
            # The data is a property of the entity, positioned in the field "targetProperty"
            elif wdDataInformation["type"] == "inValue":
                realValue = currentInformation[wdDataInformation["targetProperty"]]

            # The data is a datetime
            elif wdDataInformation["type"] == "date":
                realValue = getDateFromInformation(
                    currentInformation["time"],
                    currentInformation["precision"]
                )

        # Set the final value
        artistExtractedInformation[keyValue] = realValue
    
    return artistExtractedInformation

# %%
# Get the same-formatted artist information retrieved by MusicBrainz
def getArtistInformationMB(artistInformation):
    artistExtractedInformation = {}

    # MusicBrainz doesn't provide separated Name and Surnames
    artistExtractedInformation["name"] = None
    artistExtractedInformation["surname"] = None

    # Search for the legal name in the aliases
    try:
        artistExtractedInformation["birthName"] = None
        
        for artistAlias in artistInformation["aliases"]:
            if artistAlias["type"] == "Legal name":
                artistExtractedInformation["birthName"] = artistAlias["name"]
                
                # Often the sort name is in the form "surname, name"
                nameAndSurname = artistAlias["sort-name"].split(",")
                artistExtractedInformation["surname"] = [nameAndSurname[0].strip()]
                artistExtractedInformation["name"] = [nameAndSurname[1].strip()]
    except:
        artistExtractedInformation["birthName"] = None

    # If there is the life-span begin (birthDate for person, foundation for group), then set it as birthDate
    try:
        artistExtractedInformation["birthDate"] = artistInformation["life-span"]["begin"]
    except:
        artistExtractedInformation["birthDate"] = None
    
    # If there is the life-span end (deathDate for person, disbandment for group), then set it as deathDate
    try:
        artistExtractedInformation["deathDate"] = artistInformation["life-span"]["end"]
    except:
        artistExtractedInformation["deathDate"] = None
    
    # If there is the country iso code, then set it as country
    try:
        artistExtractedInformation["country"] = artistInformation["country"]
    except:
        artistExtractedInformation["country"] = None

    return artistExtractedInformation

# %% [markdown]
# ### People Object Generator Utilities

# %%
# Generate the object to insert in the DataFrame
def generatePeopleObject(peopleInfo):
    # Set the complete name, the name and the surname
    completeName = peopleInfo["birthName"] if not peopleInfo["birthName"] is None else peopleInfo["entityName"]

    # Name and Surname are arrays of strings (if a person has more than one name or surname)
    name = peopleInfo["name"]
    surname = peopleInfo["surname"]

    # If there is no name, but there is surname and complete name
    # retrieve the name by substracting the surname from the complete name
    if name is None and not surname is None and not completeName is None:
        # Use as position to cut only the first surname
        # This because I don't know how surnames are concatenated (by a -, or by space or other chars)
        if completeName.find(surname[0]) >= 0:
            surnamePosition = completeName.find(surname[0]) - 1
            name = completeName[:surnamePosition].strip()

        # Set the final surname joining the arrays
        surname = " ".join(surname)

    # If there is no surname, but there is name and complete name
    # retrieve the surname by substracting the name from the complete name
    elif not name is None and surname is None and not completeName is None:
        # Use as position to cut only the last name
        # This because I don't know how names are concatenated (by a -, or by space or other chars)
        if completeName.find(name[-1]) >= 0:
            namePosition = completeName.find(name[-1]) + len(name[-1])
            surname = completeName[namePosition:].strip()

        # Set the final name joining the arrays
        name = " ".join(name)

    # If there is no name, no surname but there is complete name
    # retrieve the name and the surname by dividing at the first space
    # If there are no space, set as name the complete name, and null for the surname
    elif name is None and surname is None and not completeName is None:
        namePosition = completeName.find(" ")
        surnamePosition = completeName.find(" ")
        
        if namePosition >= 0:
            name = completeName[:surnamePosition].strip()
            surname = completeName[namePosition:].strip()
        else:
            name = completeName
    
    # If there are both name and surname, set the final name and surname joining the arrays
    elif not name is None and not surname is None:
        name = " ".join(name)
        surname = " ".join(surname)
    
    # If the name or the surname is an empty string, consider it as null
    name = name if not name is None and len(name) > 0 else None
    surname = surname if not surname is None and len(surname) > 0 else None

    # Get and setup the artist information needed
    peopleObject = {
        "id": peopleInfo["wdID"] if not peopleInfo["wdID"] is None else peopleInfo["mbID"],
        "name": name,
        "surname": surname,
        "birthdate": peopleInfo["birthDate"],
        "deathdate": peopleInfo["deathDate"],
        "nationality": peopleInfo["country"],
        "artist": peopleInfo["artistID"],
        "complete_name": peopleInfo["birthName"],
        "entity_name": peopleInfo["entityName"],
    }

    return peopleObject

# %% [markdown]
# ### Query Utilities

# %%
# Try to get the best result from the WikiData query
def chooseBestQueryResult(queryResults):
    # If there are no results, return null
    if queryResults is None or not "query" in queryResults.keys():
        return None
    
    # WikiData query results are in query --> search
    queryResults = queryResults["query"]["search"]

    # If there are no query results, return null
    if len(queryResults) <= 0:
        return None
    
    print("\n🔍 [SEARCH RESULTS]")

    # Get an array of possibile results
    artistResults = []
    for queryResult in queryResults:
        # Snippet is a brief description of the entity
        querySnippet = queryResult["snippet"].lower()

        # If there are one or more of the keywords, than probably the result is a valid one
        # keywords are in order of importance, so for example if there are two results
        # containing the first one the word "artist" and the second one the word "rapper"
        # the second one will be chosen
        keyWords = [
                        "dj",
                        "singer",
                        "songwriter",
                        "rapper",
                        "duo",
                        "trio",
                        "group",
                        "band",
                        "orchestra",
                        "producer",
                        "music",
                        "artist"
                ]
        
        # If there are one or more of the banned keyword, the result is not considered
        bannedKeyWords = [
                            "album",
                            "discography",
                            "single",
                            "song ",
                            "wikimedia",
                            "film"
                        ]

        # Create an array with the positions of where each keyword has been found (-1 if not found)
        # Both for keywords and banned keywords
        keyFindResults = np.array([querySnippet.find(keyWord)
                                    for keyWord in keyWords])
        bannedKeyFindResults = np.array([querySnippet.find(keyWord)
                                            for keyWord in bannedKeyWords])

        # Get the keywords found (their position in the array of keywords)
        matchedKeys = np.where(keyFindResults >= 0)[0]
        bannedMatchedKeys = np.where(bannedKeyFindResults >= 0)[0]

        # Check if there is a match
        hasMatch = False

        # If there are no banned words and there is at least one keyword, than there is a match
        if len(bannedMatchedKeys) <= 0 and len(matchedKeys) > 0:
            hasMatch = True
            artistResults.append(matchedKeys)
        
        # Otherwise there is no match
        else:
            artistResults.append([])

        # Print the query (with --> if probably a valid match)
        hasMatchStr = "--> " if hasMatch else "- "
        print(hasMatchStr + querySnippet)

    # For each query, get the index of the more important matched word, or infinity if no matched words
    # Other algorithms probably can be used, for example considering also the number of matches
    artistResults = [k[0] if len(k) > 0 else np.inf for k in artistResults]

    # If there are no matches, return null
    if np.min(artistResults) == np.inf:
        return None

    # Then select the result with the minimum value
    artistResult = queryResults[np.argmin(artistResults)]
        
    return artistResult

# %%
# Try to get the best result from MusicBrainz query
def chooseBestQueryResultMB(queryResults, expectedArtist=None):
    # If there are no results, return null
    if queryResults is None or not "artists" in queryResults.keys():
        return None
    
    # MusicBrainz (artists) query results are in query --> artists
    queryResults = queryResults["artists"]
    
    # If there are no query results, return null
    if len(queryResults) <= 0:
        return None

    # By default, get the first result
    artistResult = queryResults[0]

    # If the name of the artist is passed, try to get a best match
    if not expectedArtist is None:
        for result in queryResults:
            # If the expected artist name is contained in the result name, than there is a match
            if expectedArtist.lower() in result["name"].lower():
                artistResult = result
                break
    
    # Get the artist information from MusicBrainz
    artistResult = mbGetArtist(artistResult["id"])

    # Set also the "title" and the "snippet", to get a object equal to the WikiData one
    if not artistResult is None:
        # Set as title the WikiData entity ID of the artist
        artistResult["title"] = getMBWikiDataEntityID(artistResult)
        # And as snippet the name of the artist
        artistResult["snippet"] = artistResult["name"]

    return artistResult

# %% [markdown]
# ## Data Retrieval

# %%
# Load the CSV files in memory
artists = pd.read_csv(artistsPath, sep=",", index_col="id")

# %%
peopleDF = None
peopleCols = ["id", "name", "surname", "birthdate", "deathdate",
              "nationality", "artist", "complete_name", "entity_name"]

# %%
# Setup DataFrames
peopleDF = pd.DataFrame([], columns=peopleCols)

# %%
# Iterate over the album DataFrame
index = 0

#for artistID, row in zip(["7DMveApC7UnC2NPfPvlHSU"], [{"name": "Cheat Codes"}]):
#for artistID, row in zip(["0vR2qb8m9WHeZ5ByCbimq2"], [{"name": "Reik"}]):
#for artistID, row in zip(["2T1aUibqR2QC2sINIDQOAK"], [{"name": "Mambo Kingz"}]):

for artistID, row in artists.iterrows():
    artistName = str(row["name"])

    print("\n\n\n🧑‍🎤 [[" + artistName.upper() + "]]")

    # Search the artist from MusicBrainz
    mbQueryResults = mbQuery(artistName)
    mbArtistResult = chooseBestQueryResultMB(mbQueryResults, artistName)
    artistResult = mbArtistResult.copy() if not mbArtistResult is None else None

    # If on MusicBrainz there isn't the wanted artist or it doesn't have WikiData page
    # Try to search directly on WikiData
    if artistResult is None or artistResult["title"] is None:
        print("\n🛑 [NO MATCHES ON MUSICBRAINZ, TRYING TO WIKIDATA]")
        wdQueryResults = wdQuery(artistName)
        artistResult = chooseBestQueryResult(wdQueryResults)
    
    # If there are is no match also on WikiData, then skip the artist
    if artistResult is None:
        print("\n🛑 [NO MATCHES ON WIKIDATA]")
        continue
    
    # Log the final choose
    print("\n✔️ [FINAL CHOOSE] " + artistResult["title"] +
            " - " + artistResult["snippet"])

    # Get the entityID. WikiData returns it in the title field
    entityID = artistResult["title"]

    # Get the WikiData entity data
    entityObject = wdGetEntity(entityID)

    # Get the WikiData claims of the entity. Claims is the list of properties
    entityClaims = None
    # The entity name is temporary the title
    entityName = artistResult["title"]

    # If there are properties, set the entity claims
    # And set the name as the entity title (the title of the WikiData page)
    if "claims" in entityObject.keys():
        entityClaims = entityObject["claims"]
        entityName = getEntityTitle(entityObject)

    # List all the members of the artist (if one the artist is a person, otherwise this will a list of persons)
    artistMembers = []

    # Use MusicBrainz information or not
    useMusicBrainz = False

    # If there is a WikiData page
    if not entityClaims is None:
        # If the WikiData entity has the property "instanceOf" to "human", then the artist is a single person artist
        if WD_MAP["instanceOf"] in entityClaims.keys() and getDataValue(entityClaims, WD_MAP["instanceOf"])["id"] == WD_MAP["human"]:
            print("\n👨 [SINGLE ARTIST]")
            # Get the information from WikiData
            artistInformation = getArtistInformation(entityClaims)
            # And set other additional information like the artist name, the entity title and the WikiData ID
            artistInformation["artistID"] = artistID
            artistInformation["artistName"] = artistName
            artistInformation["entityName"] = entityName
            artistInformation["mbID"] = mbArtistResult["id"] if not mbArtistResult is None else None
            artistInformation["wdID"] = entityID

            # And add it to the array of artists
            artistMembers.append(artistInformation)
        
        # Otherwise, if the WikiData entity has the property "hasPart", then I can get the list of group members
        elif WD_MAP["hasPart"] in entityClaims.keys():
            print("\n👪 [MEMBERS]")
            # Get only the "hasPart" property
            groupInformation = getSubsetOfKeys(entityClaims, GROUP_KEYS)
            # And get the ids of the WikiData pages as an array
            groupMembers = getDataValue(groupInformation, "hasPart", expectArray=True)

            # For each member, get the data
            for groupMember in groupMembers:
                # Get the WikiData entity
                memberEntity = wdGetEntity(groupMember["id"])

                # If there is a valid WikiData page
                if not memberEntity is None and "claims" in memberEntity.keys():
                    # Get the properties and the title of the page
                    memberEntityClaims = memberEntity["claims"]
                    memberEntityName = getEntityTitle(memberEntity)
                    
                    # And set the information of the artist
                    artistInformation = getArtistInformation(memberEntityClaims)
                    artistInformation["artistID"] = artistID
                    artistInformation["artistName"] = artistName
                    artistInformation["entityName"] = memberEntityName
                    artistInformation["mbID"] = mbArtistResult["id"] if not mbArtistResult is None else None
                    artistInformation["wdID"] = groupMember["id"]

                    # And add it to the array of artists
                    artistMembers.append(artistInformation)
        
        # Otherwise probably the WikiData entity is neither a human neither a group, so try to use MusicBrainz data
        else:
            print("\n🛑 [NO INFORMATION TO RETRIEVE, TRYING WITH MUSICBRAINZ DATA]")
            useMusicBrainz = True

    # Otherwise try to use MusicBrainz data
    else:
        print("\n🛑 [NO WIKIDATA PAGE, TRYING WITH MUSICBRAINZ DATA]")
        useMusicBrainz = True

    # If no data on WikiData, try to get the information from MusicBrainz
    if useMusicBrainz:
        if not mbArtistResult is None:
            # If the artist is a person get the information
            if mbArtistResult["type"] == "Person":
                mbArtistInformation = getArtistInformationMB(mbArtistResult)
                mbArtistInformation["entityName"] = mbArtistResult["name"]
                mbArtistInformation["artistName"] = artistName
                mbArtistInformation["artistID"] = artistID
                mbArtistInformation["mbID"] = mbArtistResult["id"]
                mbArtistInformation["wdID"] = None
                            
                artistMembers.append(mbArtistInformation)
            
             # If the artist is a group get the information
            elif mbArtistResult["type"] == "Group":
                # Get the members of the group. Since in the mbArtistResult artist relationships are not retrieved,
                # with downloadMember=True I force to get the artist information from the web
                mbGroupMembers = getMBGroupMembers(mbArtistResult, downloadMembers=True)

                # Add the group members
                if not mbGroupMembers is None:
                    for mbGroupMember in mbGroupMembers:
                        if not mbGroupMember is None:
                            mbMemberInformation = getArtistInformationMB(mbGroupMember)
                            mbMemberInformation["entityName"] = mbGroupMember["name"]
                            mbMemberInformation["artistName"] = artistName
                            mbMemberInformation["artistID"] = artistID
                            mbMemberInformation["mbID"] = mbGroupMember["id"]
                            mbMemberInformation["wdID"] = None

                            artistMembers.append(mbMemberInformation)

            else:
                print("🛑 [NO MUSICBRAINZ DATA]")
        else:
            print("🛑 [NO MUSICBRAINZ DATA]")
    
    # Create a list of people objects to insert in the DataFrame
    peopleObjList = []
    print("\n🗃️ [PEOPLE RETRIEVED]")
    for peopleInfo in artistMembers:
        peopleObject = generatePeopleObject(peopleInfo)
        
        print(peopleObject["entity_name"] + ": " + json.dumps(peopleObject))
        
        peopleObjList.append(list(peopleObject.values()))

    # Create rows DataFrame for the people
    peopleObjDF = pd.DataFrame(peopleObjList, columns=peopleCols)

    # Add the people info to the DataFrame
    peopleDF = pd.concat([peopleDF, peopleObjDF], ignore_index=True)

    # Print stats every 5000 people
    '''
    if index % 5000 == 0:
        print("\n\n🎧 [STATUS INFO #{row}]".format(row=index))
        print(peopleDF.info())
    '''
    
    # Save DataFrame to file every 100 people
    if index % 100 == 0:
        print("\n\n💾 [STATUS INFO #{row}] Dataset saved\n".format(row=index))
        peopleDF.to_csv(peoplePath)
    
    index += 1

# Print info about the DataFrames
print(peopleDF.info())
# Out:
# 🧑‍🎤 [[THE WEEKND]]
#
# ✔️ [FINAL CHOOSE] Q2121062 - The Weeknd
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# The Weeknd: {"id": "Q2121062", "name": "Tesfaye", "surname": "Tesfaye", "birthdate": "1990-02-16", "deathdate": null, "nationality": "CA", "artist": "1Xyo4u8uXC1ZmMpatF05PJ", "complete_name": "Abel Makkonen Tesfaye", "entity_name": "The Weeknd"}
#
#
# 💾 [STATUS INFO #0] Dataset saved
#
#
#
#
# 🧑‍🎤 [[DAFT PUNK]]
#
# ✔️ [FINAL CHOOSE] Q185828 - Daft Punk
#
# 👪 [MEMBERS]
#
# 🗃️ [PEOPLE RETRIEVED]
# Thomas Bangalter: {"id": "Q471656", "name": "Bangalter", "surname": "Bangalter", "birthdate": "1975-01-03", "deathdate": null, "nationality": "FR", "artist": "4tZwfgrHOc3mvqYlEYSvVi", "complete_name": null, "entity_name": "Thomas Bangalter"}
# Guy-Manuel de Homem-Christo: {"id": "Q471650", "name": "de Homem Christo", "surname": "de Homem Christo", "birthdate": "1974-02-08", "deathdate": null, "nationality": "FR", "artist": "4tZwfgrHOc3mvqYlEYSvVi", "complete_name": "Guillaume Emmanuel de Homem-Christo", "entity_name": "Guy-Manuel de Homem-Christo"}
#
#
#
# 🧑‍🎤 [[THE CHAINSMOKERS]]
#
# ✔️ [FINAL CHOOSE] Q7721993 - The Chainsmokers
#
# 👪 [MEMBERS]
#
# 🗃️ [PEOPLE RETRIEVED]
# Andrew Taggart: {"id": "Q48774228", "name": "Taggart", "surname": "Taggart", "birthdate": null, "deathdate": null, "nationality": "US", "artist": "69GGBxA162lTqCwzJG5jLp", "complete_name": null, "entity_name": "Andrew Taggart"}
# Alex Pall: {"id": "Q48774469", "name": "Pall", "surname": "Pall", "birthdate": null, "deathdate": null, "nationality": "US", "artist": "69GGBxA162lTqCwzJG5jLp", "complete_name": null, "entity_name": "Alex Pall"}
#
#
#
# 🧑‍🎤 [[HALSEY]]
#
# ✔️ [FINAL CHOOSE] Q18534249 - Halsey
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Halsey: {"id": "Q18534249", "name": "Frangipane", "surname": "Frangipane", "birthdate": "1994-09-29", "deathdate": null, "nationality": "US", "artist": "26VFTg2z8YR0cCuwLzESi2", "complete_name": "Ashley Nicolette Frangipane", "entity_name": "Halsey"}
#
#
#
# 🧑‍🎤 [[DJ SNAKE]]
#
# ✔️ [FINAL CHOOSE] Q16728588 - DJ Snake
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# DJ Snake: {"id": "Q16728588", "name": "Grigahcine", "surname": "Grigahcine", "birthdate": "1986-06-13", "deathdate": null, "nationality": "DZ", "artist": "540vIaP2JwjQb9dm3aArA4", "complete_name": "William Grigahcine", "entity_name": "DJ Snake"}
#
#
#
# 🧑‍🎤 [[JUSTIN BIEBER]]
#
# ✔️ [FINAL CHOOSE] Q34086 - Justin Bieber
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Justin Bieber: {"id": "Q34086", "name": "Bieber", "surname": "Bieber", "birthdate": "1994-03-01", "deathdate": null, "nationality": "CA", "artist": "1uNFoZAHBGtllmzznpCI3s", "complete_name": "Justin Drew Bieber", "entity_name": "Justin Bieber"}
#
#
#
# 🧑‍🎤 [[CLEAN BANDIT]]
#
# ✔️ [FINAL CHOOSE] Q11838808 - Clean Bandit
#
# 👪 [MEMBERS]
#
# 🗃️ [PEOPLE RETRIEVED]
# Grace Chatto: {"id": "Q29033349", "name": "Chatto", "surname": "Chatto", "birthdate": "1985-12-10", "deathdate": null, "nationality": "GB", "artist": "6MDME20pz9RveH9rEXvrOM", "complete_name": "Grace Elizabeth Chatto", "entity_name": "Grace Chatto"}
# Jack Patterson: {"id": "Q64754197", "name": "Patterson", "surname": "Patterson", "birthdate": "1985-07-02", "deathdate": null, "nationality": "GB", "artist": "6MDME20pz9RveH9rEXvrOM", "complete_name": null, "entity_name": "Jack Patterson"}
#
#
#
# 🧑‍🎤 [[SEAN PAUL]]
#
# ✔️ [FINAL CHOOSE] Q200577 - Sean Paul
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Sean Paul: {"id": "Q200577", "name": "Henriques", "surname": "Henriques", "birthdate": "1973-01-09", "deathdate": null, "nationality": "JM", "artist": "3Isy6kedDrgPYoTS1dazA9", "complete_name": "Sean Paul Ryan Francis Henriques", "entity_name": "Sean Paul"}
#
#
#
# 🧑‍🎤 [[ANNE-MARIE]]
#
# 🛑 [NO MATCHES ON MUSICBRAINZ, TRYING TO WIKIDATA]
#
# 🔍 [SEARCH RESULTS]
# - female given name
# --> english singer
# - asteroid
# - female given name
# - wikimedia disambiguation page
# - female given name
# - swedish politician
# - swedish politician
# --> french singer-songwriter
# --> french singer
# - 1936 film by raymond bernard
# - american actress and impressionist
# -
# - danish sculptor, author of the equestrian statue of king christian ix
# - belgian politician (1949-2015)
# - female given name
# - french basketball player and athletics competitor
# -
# - swiss film director, screen writer and actress
# - british politician (born 1969)
#
# ✔️ [FINAL CHOOSE] Q25396976 - English singer
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Anne-Marie: {"id": "Q25396976", "name": "Nicholson", "surname": "Nicholson", "birthdate": "1991-04-07", "deathdate": null, "nationality": "GB", "artist": "1zNqDE7qDGCsyzJwohVaoX", "complete_name": "Anne-Marie Rose Nicholson", "entity_name": "Anne-Marie"}
#
#
#
# 🧑‍🎤 [[DRAKE]]
#
# ✔️ [FINAL CHOOSE] Q33240 - Drake
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Drake: {"id": "Q33240", "name": "Graham", "surname": "Graham", "birthdate": "1986-10-24", "deathdate": null, "nationality": "CA", "artist": "3TVXtAsR1Inumwj472S9r4", "complete_name": "Aubrey Drake Graham", "entity_name": "Drake"}
#
#
#
# 🧑‍🎤 [[WIZKID]]
#
# ✔️ [FINAL CHOOSE] Q16233663 - Wizkid
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Wizkid: {"id": "Q16233663", "name": "Ibrahim Balogun", "surname": "Ibrahim Balogun", "birthdate": "1990-07-16", "deathdate": null, "nationality": "NG", "artist": "3tVQdUvClmAT7URs9V3rsp", "complete_name": "Ayodeji Ibrahim Balogun", "entity_name": "Wizkid"}
#
#
#
# 🧑‍🎤 [[KYLA]]
#
# ✔️ [FINAL CHOOSE] Q153234 - Kyla
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Kyla: {"id": "Q153234", "name": null, "surname": null, "birthdate": "1981-01-05", "deathdate": null, "nationality": "PH", "artist": "77DAFfvm3O9zT5dIoG0eIO", "complete_name": null, "entity_name": "Kyla"}
#
#
#
# 🧑‍🎤 [[BRUNO MARS]]
#
# ✔️ [FINAL CHOOSE] Q1450 - Bruno Mars
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Bruno Mars: {"id": "Q1450", "name": "Hernandez", "surname": "Hernandez", "birthdate": "1985-10-08", "deathdate": null, "nationality": "US", "artist": "0du5cEVh5yTK9QJze8zA0C", "complete_name": "Peter Gene Hernandez", "entity_name": "Bruno Mars"}
#
#
#
# 🧑‍🎤 [[MAROON 5]]
#
# ✔️ [FINAL CHOOSE] Q182223 - Maroon 5
#
# 👪 [MEMBERS]
#
# 🗃️ [PEOPLE RETRIEVED]
# Adam Levine: {"id": "Q219631", "name": "Levine", "surname": "Levine", "birthdate": "1979-03-18", "deathdate": null, "nationality": "US", "artist": "04gDigrS5kc9YWfZHwBETP", "complete_name": "Adam Noah Levine", "entity_name": "Adam Levine"}
# Jesse Carmichael: {"id": "Q459375", "name": "Carmichael", "surname": "Carmichael", "birthdate": "1979-04-02", "deathdate": null, "nationality": "US", "artist": "04gDigrS5kc9YWfZHwBETP", "complete_name": null, "entity_name": "Jesse Carmichael"}
# Mickey Madden: {"id": "Q1200118", "name": "Madden", "surname": "Madden", "birthdate": "1979-05-13", "deathdate": null, "nationality": "US", "artist": "04gDigrS5kc9YWfZHwBETP", "complete_name": null, "entity_name": "Mickey Madden"}
# James Valentine: {"id": "Q445136", "name": "Valentine", "surname": "Valentine", "birthdate": "1978-10-05", "deathdate": null, "nationality": "US", "artist": "04gDigrS5kc9YWfZHwBETP", "complete_name": null, "entity_name": "James Valentine"}
# Ryan Dusick: {"id": "Q736673", "name": "Dusick", "surname": "Dusick", "birthdate": "1977-09-19", "deathdate": null, "nationality": "US", "artist": "04gDigrS5kc9YWfZHwBETP", "complete_name": null, "entity_name": "Ryan Dusick"}
# Matt Flynn: {"id": "Q1200152", "name": "Flynn", "surname": "Flynn", "birthdate": "1970-05-23", "deathdate": null, "nationality": "US", "artist": "04gDigrS5kc9YWfZHwBETP", "complete_name": null, "entity_name": "Matt Flynn"}
#
#
#
# 🧑‍🎤 [[KENDRICK LAMAR]]
#
# ✔️ [FINAL CHOOSE] Q130798 - Kendrick Lamar
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Kendrick Lamar: {"id": "Q130798", "name": "Duckworth", "surname": "Duckworth", "birthdate": "1987-06-17", "deathdate": null, "nationality": "US", "artist": "2YZyLoL8N0Wb9xBt1NhZWg", "complete_name": "Kendrick Lamar Duckworth", "entity_name": "Kendrick Lamar"}
#
#
#
# 🧑‍🎤 [[RAE SREMMURD]]
#
# ✔️ [FINAL CHOOSE] Q18123226 - Rae Sremmurd
#
# 👪 [MEMBERS]
#
# 🗃️ [PEOPLE RETRIEVED]
# Slim Jxmmi: {"id": "Q31401627", "name": "Brown", "surname": "Brown", "birthdate": "1991-12-29", "deathdate": null, "nationality": "US", "artist": "7iZtZyCzp3LItcw1wtPI3D", "complete_name": "Aaquil Iben Shamon Brown", "entity_name": "Slim Jxmmi"}
# Swae Lee: {"id": "Q30103025", "name": "Brown", "surname": "Brown", "birthdate": "1993-06-07", "deathdate": null, "nationality": "US", "artist": "7iZtZyCzp3LItcw1wtPI3D", "complete_name": "Khalif Malik Ibn Shaman Brown", "entity_name": "Swae Lee"}
# Lil Pantz: {"id": "Q44120002", "name": "Pantz", "surname": "Pantz", "birthdate": null, "deathdate": null, "nationality": null, "artist": "7iZtZyCzp3LItcw1wtPI3D", "complete_name": null, "entity_name": "Lil Pantz"}
# BoBo Swae: {"id": "Q44120074", "name": "Swae", "surname": "Swae", "birthdate": "1901", "deathdate": null, "nationality": null, "artist": "7iZtZyCzp3LItcw1wtPI3D", "complete_name": null, "entity_name": "BoBo Swae"}
#
#
#
# 🧑‍🎤 [[GUCCI MANE]]
#
# ✔️ [FINAL CHOOSE] Q206032 - Gucci Mane
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Gucci Mane: {"id": "Q206032", "name": "Davis", "surname": "Davis", "birthdate": "1980-02-12", "deathdate": null, "nationality": "US", "artist": "13y7CgLHjMVRMDqxdx0Xdo", "complete_name": "Radric Delantic Davis", "entity_name": "Gucci Mane"}
#
#
#
# 🧑‍🎤 [[SHAKIRA]]
#
# ✔️ [FINAL CHOOSE] Q34424 - Shakira
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Shakira: {"id": "Q34424", "name": "Mebarak", "surname": "Mebarak", "birthdate": "1977-02-02", "deathdate": null, "nationality": "CO", "artist": "0EmeFodog0BfCgMzAIvKQp", "complete_name": "Shakira Isabel Mebarak Ripoll", "entity_name": "Shakira"}
#
#
#
# 🧑‍🎤 [[MALUMA]]
#
# ✔️ [FINAL CHOOSE] Q17517186 - Maluma
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Maluma: {"id": "Q17517186", "name": "Londo\u00f1o", "surname": "Londo\u00f1o", "birthdate": "1994-01-28", "deathdate": null, "nationality": "CO", "artist": "1r4hJ1h58CWwUQe3MxPuau", "complete_name": "Juan Luis Londo\u00f1o Arias", "entity_name": "Maluma"}
#
#
#
# 🧑‍🎤 [[ZAYN]]
#
# ✔️ [FINAL CHOOSE] Q3626950 - ZAYN
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Zayn Malik: {"id": "Q3626950", "name": "Malik", "surname": "Malik", "birthdate": "1993-01-12", "deathdate": null, "nationality": "GB", "artist": "5ZsFI1h6hIdQRw2ti0hz81", "complete_name": "Zain Javadd Malik", "entity_name": "Zayn Malik"}
#
#
#
# 🧑‍🎤 [[TAYLOR SWIFT]]
#
# ✔️ [FINAL CHOOSE] Q26876 - Taylor Swift
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Taylor Swift: {"id": "Q26876", "name": "Swift", "surname": "Swift", "birthdate": "1989-12-13", "deathdate": null, "nationality": "US", "artist": "06HL4z0CvFAxyc27GXpf02", "complete_name": "Taylor Alison Swift", "entity_name": "Taylor Swift"}
#
#
#
# 🧑‍🎤 [[JAMES ARTHUR]]
#
# ✔️ [FINAL CHOOSE] Q717626 - James Arthur
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# James Arthur: {"id": "Q717626", "name": "Arthur", "surname": "Arthur", "birthdate": "1988-03-02", "deathdate": null, "nationality": "GB", "artist": "4IWBUUAFIplrNtaOHcJPRM", "complete_name": "James Andrew Arthur", "entity_name": "James Arthur"}
#
#
#
# 🧑‍🎤 [[MIGOS]]
#
# ✔️ [FINAL CHOOSE] Q15777045 - Migos
#
# 👪 [MEMBERS]
#
# 🗃️ [PEOPLE RETRIEVED]
# Takeoff: {"id": "Q48719890", "name": "Ball", "surname": "Ball", "birthdate": "1994-06-18", "deathdate": null, "nationality": "US", "artist": "6oMuImdp5ZcFhWP0ESe6mG", "complete_name": "Kirshnik Khari Ball", "entity_name": "Takeoff"}
# Quavo: {"id": "Q30072039", "name": "Marshall", "surname": "Marshall", "birthdate": "1991-04-02", "deathdate": null, "nationality": "US", "artist": "6oMuImdp5ZcFhWP0ESe6mG", "complete_name": "Quavious Keyate Marshall", "entity_name": "Quavo"}
# Offset: {"id": "Q30612480", "name": "Cephus", "surname": "Cephus", "birthdate": "1991-12-14", "deathdate": null, "nationality": "US", "artist": "6oMuImdp5ZcFhWP0ESe6mG", "complete_name": "Kiari Kendrell Cephus", "entity_name": "Offset"}
#
#
#
# 🧑‍🎤 [[LIL UZI VERT]]
#
# ✔️ [FINAL CHOOSE] Q23771950 - Lil Uzi Vert
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Lil Uzi Vert: {"id": "Q23771950", "name": "Woods", "surname": "Woods", "birthdate": "1995-07-31", "deathdate": null, "nationality": "US", "artist": "4O15NlyKLIASxsJ0PrXPfz", "complete_name": "Symere Bysil Woods", "entity_name": "Lil Uzi Vert"}
#
#
#
# 🧑‍🎤 [[MAJOR LAZER]]
#
# ✔️ [FINAL CHOOSE] Q2604214 - Major Lazer
#
# 👪 [MEMBERS]
#
# 🗃️ [PEOPLE RETRIEVED]
# Diplo: {"id": "Q533781", "name": "Pentz", "surname": "Pentz", "birthdate": "1978-11-10", "deathdate": null, "nationality": "US", "artist": "738wLrAtLtCtFOLvQBXOXp", "complete_name": "Thomas Wesley Pentz", "entity_name": "Diplo"}
# Jillionaire: {"id": "Q20684243", "name": null, "surname": null, "birthdate": "1978-04-03", "deathdate": null, "nationality": "TT", "artist": "738wLrAtLtCtFOLvQBXOXp", "complete_name": null, "entity_name": "Jillionaire"}
# Switch: {"id": "Q3101707", "name": null, "surname": null, "birthdate": "2000", "deathdate": null, "nationality": "GB", "artist": "738wLrAtLtCtFOLvQBXOXp", "complete_name": null, "entity_name": "Switch"}
#
#
#
# 🧑‍🎤 [[MØ]]
#
# ✔️ [FINAL CHOOSE] Q10670047 - MØ
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# MØ: {"id": "Q10670047", "name": "\u00d8rsted", "surname": "\u00d8rsted", "birthdate": "1988-08-13", "deathdate": null, "nationality": "DK", "artist": "0bdfiayQAKewqEvaU6rXCv", "complete_name": null, "entity_name": "M\u00d8"}
#
#
#
# 🧑‍🎤 [[MARTIN GARRIX]]
#
# ✔️ [FINAL CHOOSE] Q14544318 - Martin Garrix
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Martin Garrix: {"id": "Q14544318", "name": "Garritsen", "surname": "Garritsen", "birthdate": "1996-05-14", "deathdate": null, "nationality": "NL", "artist": "60d24wfXkVzDSfLS6hyCjZ", "complete_name": "Martijn Gerard Garritsen", "entity_name": "Martin Garrix"}
#
#
#
# 🧑‍🎤 [[BEBE REXHA]]
#
# ✔️ [FINAL CHOOSE] Q16185856 - Bebe Rexha
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Bebe Rexha: {"id": "Q16185856", "name": "Rexha", "surname": "Rexha", "birthdate": "1989-08-30", "deathdate": null, "nationality": "US", "artist": "64M6ah0SkkRsnPGtGiRAbb", "complete_name": "Bleta Rexha", "entity_name": "Bebe Rexha"}
#
#
#
# 🧑‍🎤 [[ARIANA GRANDE]]
#
# ✔️ [FINAL CHOOSE] Q151892 - Ariana Grande
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Ariana Grande: {"id": "Q151892", "name": "Grande-Butera", "surname": "Grande-Butera", "birthdate": "1993-06-26", "deathdate": null, "nationality": "US", "artist": "66CXWjxzNUsdJxJ2JdwvnR", "complete_name": "Ariana Grande-Butera", "entity_name": "Ariana Grande"}
#
#
#
# 🧑‍🎤 [[NICKI MINAJ]]
#
# ✔️ [FINAL CHOOSE] Q162202 - Nicki Minaj
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Nicki Minaj: {"id": "Q162202", "name": "Maraj Petty", "surname": "Maraj Petty", "birthdate": "1982-12-08", "deathdate": null, "nationality": "TT", "artist": "0hCNtLu0JehylgoiP8L4Gh", "complete_name": "Onika Tanya Maraj", "entity_name": "Nicki Minaj"}
#
#
#
# 🧑‍🎤 [[STARLEY]]
#
# ✔️ [FINAL CHOOSE] Q28054068 - Starley
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Starley: {"id": "Q28054068", "name": null, "surname": null, "birthdate": "1987-10-03", "deathdate": null, "nationality": "AU", "artist": "02A3cEvlLLCbIMVDrK2GHV", "complete_name": null, "entity_name": "Starley"}
#
#
#
# 🧑‍🎤 [[RYAN RIBACK]]
#
# 🛑 [NO MATCHES ON MUSICBRAINZ, TRYING TO WIKIDATA]
#
# 🔍 [SEARCH RESULTS]
# --> musical artist
# - 2018 single by iyes and <span class="searchmatch">ryan</span> <span class="searchmatch">riback</span>
# - 2016 single by starley
#
# ✔️ [FINAL CHOOSE] Q42224112 - musical artist
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Ryan Riback: {"id": "Q42224112", "name": "Riback", "surname": "Riback", "birthdate": "1981-09-19", "deathdate": null, "nationality": null, "artist": "33JQK4UoS2aMPYBfdB5Ftt", "complete_name": null, "entity_name": "Ryan Riback"}
#
#
#
# 🧑‍🎤 [[JUSTIN TIMBERLAKE]]
#
# ✔️ [FINAL CHOOSE] Q43432 - Justin Timberlake
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Justin Timberlake: {"id": "Q43432", "name": "Timberlake", "surname": "Timberlake", "birthdate": "1981-01-31", "deathdate": null, "nationality": "US", "artist": "31TPClRtHm23RisEBtV3X7", "complete_name": "Justin Randall Timberlake", "entity_name": "Justin Timberlake"}
#
#
#
# 🧑‍🎤 [[DAYA]]
#
# ✔️ [FINAL CHOOSE] Q21005558 - Daya
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Daya: {"id": "Q21005558", "name": "Tandon", "surname": "Tandon", "birthdate": "1998-10-24", "deathdate": null, "nationality": "US", "artist": "6Dd3NScHWwnW6obMFbl1BH", "complete_name": "Grace Martine Tandon", "entity_name": "Daya"}
#
#
#
# 🧑‍🎤 [[SHAWN MENDES]]
#
# ✔️ [FINAL CHOOSE] Q17198340 - Shawn Mendes
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Shawn Mendes: {"id": "Q17198340", "name": "Mendes", "surname": "Mendes", "birthdate": "1998-08-08", "deathdate": null, "nationality": "CA", "artist": "7n2wHs1TKAczGzO7Dd2rGr", "complete_name": "Shawn Peter Raul Mendes", "entity_name": "Shawn Mendes"}
#
#
#
# 🧑‍🎤 [[STEVE AOKI]]
#
# ✔️ [FINAL CHOOSE] Q459955 - Steve Aoki
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Steve Aoki: {"id": "Q459955", "name": "Aoki", "surname": "Aoki", "birthdate": "1977-11-30", "deathdate": null, "nationality": "US", "artist": "77AiFEVeAVj2ORpC85QVJs", "complete_name": null, "entity_name": "Steve Aoki"}
#
#
#
# 🧑‍🎤 [[LOUIS TOMLINSON]]
#
# ✔️ [FINAL CHOOSE] Q10745343 - Louis Tomlinson
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Louis Tomlinson: {"id": "Q10745343", "name": "William Tomlinson", "surname": "William Tomlinson", "birthdate": "1991-12-24", "deathdate": null, "nationality": "GB", "artist": "57WHJIHrjOE3iAxpihhMnp", "complete_name": "Louis Troy Austin", "entity_name": "Louis Tomlinson"}
#
#
#
# 🧑‍🎤 [[CALVIN HARRIS]]
#
# ✔️ [FINAL CHOOSE] Q81637 - Calvin Harris
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Calvin Harris: {"id": "Q81637", "name": "Wiles Harris", "surname": "Wiles Harris", "birthdate": "1984-01-17", "deathdate": null, "nationality": null, "artist": "7CajNmpbOovFoOoasH2HaY", "complete_name": "Adam Richard Wiles", "entity_name": "Calvin Harris"}
#
#
#
# 🧑‍🎤 [[HAILEE STEINFELD]]
#
# ✔️ [FINAL CHOOSE] Q231726 - Hailee Steinfeld
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Hailee Steinfeld: {"id": "Q231726", "name": "Steinfeld", "surname": "Steinfeld", "birthdate": "1996-12-11", "deathdate": null, "nationality": "US", "artist": "5p7f24Rk5HkUZsaS3BLG5F", "complete_name": null, "entity_name": "Hailee Steinfeld"}
#
#
#
# 🧑‍🎤 [[GREY]]
#
# 🛑 [NO MATCHES ON MUSICBRAINZ, TRYING TO WIKIDATA]
#
# 🔍 [SEARCH RESULTS]
# - intermediate color between black and white; for e.g. color of a cloud-covered sky, ash and lead
# - family name
# - australian federal electoral division
# - 2011 film by joe carnahan
# - equine coat colour
# - american voice actress
# - eye color
# - alleged extraterrestrial beings
# --> japanese rock band
# - male given name
# - wikimedia disambiguation page
# - prime minister of the united kingdom of great britain and ireland (1764-1845)
# - british politician, entomologist and cricketer (1843-1919)
# - british chemist and professor of chemistry
# - english noblewoman and deposed queen of england
# - female given name
# - american novelist
# --> american electronic music group consisting of brothers kyle and michael trewartha
# - american actress (1917-2004)
# - british liberal statesman (1862-1933)
#
# ✔️ [FINAL CHOOSE] Q28451953 - American electronic music group consisting of brothers Kyle and Michael Trewartha
#
# 🛑 [NO INFORMATION TO RETRIEVE, TRYING WITH MUSICBRAINZ DATA]
#
# 🗃️ [PEOPLE RETRIEVED]
# Grey: {"id": "8dd51778-5fba-4f75-99d3-bc3b27513aab", "name": null, "surname": null, "birthdate": "1965-09-10", "deathdate": null, "nationality": "US", "artist": "4lDBihdpMlOalxy1jkUbPl", "complete_name": null, "entity_name": "Grey"}
#
#
#
# 🧑‍🎤 [[ZEDD]]
#
# ✔️ [FINAL CHOOSE] Q21088 - Zedd
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Zedd: {"id": "Q21088", "name": "Zaslavski", "surname": "Zaslavski", "birthdate": "1989-09-02", "deathdate": null, "nationality": "RU", "artist": "2qxJFvFYMEDqd7ui6kSAcq", "complete_name": null, "entity_name": "Zedd"}
#
#
#
# 🧑‍🎤 [[MACHINE GUN KELLY]]
#
# ✔️ [FINAL CHOOSE] Q1354843 - Machine Gun Kelly
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Machine Gun Kelly: {"id": "Q1354843", "name": "Baker", "surname": "Baker", "birthdate": "1990-04-22", "deathdate": null, "nationality": "US", "artist": "6TIYQ3jFPwQSRmorSezPxX", "complete_name": "Colson Baker", "entity_name": "Machine Gun Kelly"}
#
#
#
# 🧑‍🎤 [[CAMILA CABELLO]]
#
# ✔️ [FINAL CHOOSE] Q18810940 - Camila Cabello
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Camila Cabello: {"id": "Q18810940", "name": "Cabello", "surname": "Cabello", "birthdate": "1997-03-03", "deathdate": null, "nationality": "CU", "artist": "4nDoRrQiYLoBzwC5BhVJzF", "complete_name": "Karla Camila Cabello Estrabao", "entity_name": "Camila Cabello"}
#
#
#
# 🧑‍🎤 [[TWENTY ONE PILOTS]]
#
# ✔️ [FINAL CHOOSE] Q7857806 - twenty one pilots
#
# 👪 [MEMBERS]
#
# 🗃️ [PEOPLE RETRIEVED]
# Tyler Joseph: {"id": "Q17306112", "name": "Joseph", "surname": "Joseph", "birthdate": "1988-12-01", "deathdate": null, "nationality": "US", "artist": "3YQKmKGau1PzlVlkL1iodx", "complete_name": null, "entity_name": "Tyler Joseph"}
# Joshua Dun: {"id": "Q17305889", "name": "Dun", "surname": "Dun", "birthdate": "1988-06-18", "deathdate": null, "nationality": "US", "artist": "3YQKmKGau1PzlVlkL1iodx", "complete_name": "Joshua William Dun", "entity_name": "Joshua Dun"}
#
#
#
# 🧑‍🎤 [[SIA]]
#
# ✔️ [FINAL CHOOSE] Q181484 - Sia
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Sia: {"id": "Q181484", "name": "Furler", "surname": "Furler", "birthdate": "1975-12-18", "deathdate": null, "nationality": "AU", "artist": "5WUlDfRSoLAfcVSX1WnrxN", "complete_name": "Sia Kate Isobelle Furler", "entity_name": "Sia"}
#
#
#
# 🧑‍🎤 [[PHOEBE RYAN]]
#
# ✔️ [FINAL CHOOSE] Q24450730 - Phoebe Ryan
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Phoebe Ryan: {"id": "Q24450730", "name": "Ryan", "surname": "Ryan", "birthdate": "1990-09-21", "deathdate": null, "nationality": "US", "artist": "4N874uPqBka1QiCvnCVOtr", "complete_name": null, "entity_name": "Phoebe Ryan"}
#
#
#
# 🧑‍🎤 [[CNCO]]
#
# ✔️ [FINAL CHOOSE] Q26270552 - CNCO
#
# 👪 [MEMBERS]
#
# 🗃️ [PEOPLE RETRIEVED]
# Christopher Vélez: {"id": "Q28950508", "name": "V\u00e9lez", "surname": "V\u00e9lez", "birthdate": "1995-11-23", "deathdate": null, "nationality": "EC", "artist": "0eecdvMrqBftK0M1VKhaF4", "complete_name": "Christopher Bryant V\u00e9lez Mu\u00f1oz", "entity_name": "Christopher V\u00e9lez"}
# Richard Camacho: {"id": "Q25367694", "name": "Camacho", "surname": "Camacho", "birthdate": "1997-01-22", "deathdate": null, "nationality": "US", "artist": "0eecdvMrqBftK0M1VKhaF4", "complete_name": "Richard Yashel Camacho Puello", "entity_name": "Richard Camacho"}
# Joel Pimentel: {"id": "Q41450422", "name": "Pimentel", "surname": "Pimentel", "birthdate": "1999-02-28", "deathdate": null, "nationality": "US", "artist": "0eecdvMrqBftK0M1VKhaF4", "complete_name": "Joel Pimentel De Leon", "entity_name": "Joel Pimentel"}
# Erick Brian Colón: {"id": "Q101096694", "name": "Col\u00f3n", "surname": "Col\u00f3n", "birthdate": "2001-01-03", "deathdate": null, "nationality": "CU", "artist": "0eecdvMrqBftK0M1VKhaF4", "complete_name": "Erick Brian Col\u00f3n Arista", "entity_name": "Erick Brian Col\u00f3n"}
# Zabdiel De Jesús: {"id": "Q101096577", "name": "de Jes\u00fas", "surname": "de Jes\u00fas", "birthdate": "1997-12-13", "deathdate": null, "nationality": "PR", "artist": "0eecdvMrqBftK0M1VKhaF4", "complete_name": "Zabdiel de Jes\u00fas Col\u00f3n", "entity_name": "Zabdiel De Jes\u00fas"}
# Justin Bieber: {"id": "Q34086", "name": "Bieber", "surname": "Bieber", "birthdate": "1994-03-01", "deathdate": null, "nationality": "CA", "artist": "0eecdvMrqBftK0M1VKhaF4", "complete_name": "Justin Drew Bieber", "entity_name": "Justin Bieber"}
#
#
#
# 🧑‍🎤 [[SHELLEY FKA DRAM]]
#
# ✔️ [FINAL CHOOSE] Q25138504 - Shelley
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Shelley FKA DRAM: {"id": "Q25138504", "name": "Massenburg Smith", "surname": "Massenburg Smith", "birthdate": "1988-08-03", "deathdate": null, "nationality": "US", "artist": "5M0lbkGluOPXLeFjApw8r8", "complete_name": null, "entity_name": "Shelley FKA DRAM"}
#
#
#
# 🧑‍🎤 [[LIL YACHTY]]
#
# ✔️ [FINAL CHOOSE] Q23772141 - Lil Yachty
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Lil Yachty: {"id": "Q23772141", "name": "McCollum", "surname": "McCollum", "birthdate": "1997-08-23", "deathdate": null, "nationality": "US", "artist": "6icQOAFXDZKsumw3YXyusw", "complete_name": "Miles Parks McCollum", "entity_name": "Lil Yachty"}
#
#
#
# 🧑‍🎤 [[MIKE POSNER]]
#
# ✔️ [FINAL CHOOSE] Q268284 - Mike Posner
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Mike Posner: {"id": "Q268284", "name": "Posner", "surname": "Posner", "birthdate": "1988-02-12", "deathdate": null, "nationality": "US", "artist": "2KsP6tYLJlTBvSUxnwlVWa", "complete_name": null, "entity_name": "Mike Posner"}
#
#
#
# 🧑‍🎤 [[SEEB]]
#
# ✔️ [FINAL CHOOSE] Q23579879 - Seeb
#
# 👪 [MEMBERS]
#
# 🗃️ [PEOPLE RETRIEVED]
# Simen Eriksrud: {"id": "Q12000501", "name": "Eriksrud", "surname": "Eriksrud", "birthdate": "1975-11-12", "deathdate": null, "nationality": "NO", "artist": "5iNrZmtVMtYev5M9yoWpEq", "complete_name": null, "entity_name": "Simen Eriksrud"}
# Espen Berg: {"id": "Q59238387", "name": "Berg", "surname": "Berg", "birthdate": null, "deathdate": null, "nationality": "NO", "artist": "5iNrZmtVMtYev5M9yoWpEq", "complete_name": null, "entity_name": "Espen Berg"}
#
#
#
# 🧑‍🎤 [[J BALVIN]]
#
# ✔️ [FINAL CHOOSE] Q966845 - J Balvin
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# J Balvin: {"id": "Q966845", "name": "Balvin", "surname": "Balvin", "birthdate": "1985-05-07", "deathdate": null, "nationality": "CO", "artist": "1vyhD5VmyZ7KMfW5gqLgo5", "complete_name": null, "entity_name": "J Balvin"}
#
#
#
# 🧑‍🎤 [[PHARRELL WILLIAMS]]
#
# ✔️ [FINAL CHOOSE] Q14313 - Pharrell Williams
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Pharrell Williams: {"id": "Q14313", "name": "Williams", "surname": "Williams", "birthdate": "1973-04-05", "deathdate": null, "nationality": "US", "artist": "2RdwBSPQiwcmiDo9kixcl8", "complete_name": "Pharrell Lanscilo Williams", "entity_name": "Pharrell Williams"}
#
#
#
# 🧑‍🎤 [[BIA]]
#
# ✔️ [FINAL CHOOSE] Q21005074 - BIA
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# BIA: {"id": "Q21005074", "name": "Landrau", "surname": "Landrau", "birthdate": "1991-08-16", "deathdate": null, "nationality": "US", "artist": "6veh5zbFpm31XsPdjBgPER", "complete_name": "Bianca Landrau", "entity_name": "BIA"}
#
#
#
# 🧑‍🎤 [[SKY ROMPIENDO]]
#
# 🛑 [NO MATCHES ON MUSICBRAINZ, TRYING TO WIKIDATA]
#
# 🔍 [SEARCH RESULTS]
# --> musical artist
#
# ✔️ [FINAL CHOOSE] Q108410092 - musical artist
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Sky Rompiendo: {"id": "Q108410092", "name": "Rompiendo", "surname": "Rompiendo", "birthdate": null, "deathdate": null, "nationality": null, "artist": "51XrH5fQP2oIQynuKxSWcW", "complete_name": null, "entity_name": "Sky Rompiendo"}
#
#
#
# 🧑‍🎤 [[RIHANNA]]
#
# ✔️ [FINAL CHOOSE] Q36844 - Rihanna
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Rihanna: {"id": "Q36844", "name": "Fenty", "surname": "Fenty", "birthdate": "1988-02-20", "deathdate": null, "nationality": "BB", "artist": "5pKCCKE2ajJHZ9KAiaK11H", "complete_name": "Robyn Rihanna Fenty", "entity_name": "Rihanna"}
#
#
#
# 🧑‍🎤 [[FIFTH HARMONY]]
#
# ✔️ [FINAL CHOOSE] Q3087893 - Fifth Harmony
#
# 👪 [MEMBERS]
#
# 🗃️ [PEOPLE RETRIEVED]
# Camila Cabello: {"id": "Q18810940", "name": "Cabello", "surname": "Cabello", "birthdate": "1997-03-03", "deathdate": null, "nationality": "CU", "artist": "1l8Fu6IkuTP0U5QetQJ5Xt", "complete_name": "Karla Camila Cabello Estrabao", "entity_name": "Camila Cabello"}
# Ally Brooke: {"id": "Q22965780", "name": "Hern\u00e1ndez", "surname": "Hern\u00e1ndez", "birthdate": "1993-07-07", "deathdate": null, "nationality": "US", "artist": "1l8Fu6IkuTP0U5QetQJ5Xt", "complete_name": null, "entity_name": "Ally Brooke"}
# Lauren Jauregui: {"id": "Q18921974", "name": "J\u00e1uregui", "surname": "J\u00e1uregui", "birthdate": "1996-06-27", "deathdate": null, "nationality": "US", "artist": "1l8Fu6IkuTP0U5QetQJ5Xt", "complete_name": "Lauren Michelle Jauregui Morgado", "entity_name": "Lauren Jauregui"}
# Normani: {"id": "Q28148022", "name": "Hamilton", "surname": "Hamilton", "birthdate": "1996-05-31", "deathdate": null, "nationality": "US", "artist": "1l8Fu6IkuTP0U5QetQJ5Xt", "complete_name": "Normani Kordei Hamilton", "entity_name": "Normani"}
# Dinah Jane: {"id": "Q28065951", "name": "Hansen", "surname": "Hansen", "birthdate": "1997-06-22", "deathdate": null, "nationality": "US", "artist": "1l8Fu6IkuTP0U5QetQJ5Xt", "complete_name": "Dinah Jane Hansen", "entity_name": "Dinah Jane"}
#
#
#
# 🧑‍🎤 [[TY DOLLA $IGN]]
#
# ✔️ [FINAL CHOOSE] Q7859785 - Ty Dolla $ign
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Ty Dolla $ign: {"id": "Q7859785", "name": "Griffin", "surname": "Griffin", "birthdate": "1982-04-13", "deathdate": null, "nationality": "US", "artist": "7c0XG5cIJTrrAgEC3ULPiq", "complete_name": "Tyrone William Griffin Jr.", "entity_name": "Ty Dolla $ign"}
#
#
#
# 🧑‍🎤 [[ALESSIA CARA]]
#
# ✔️ [FINAL CHOOSE] Q20090091 - Alessia Cara
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Alessia Cara: {"id": "Q20090091", "name": "Caracciolo", "surname": "Caracciolo", "birthdate": "1996-07-11", "deathdate": null, "nationality": "CA", "artist": "2wUjUUtkb5lvLKcGKsKqsR", "complete_name": "Alessia Caracciolo", "entity_name": "Alessia Cara"}
#
#
#
# 🧑‍🎤 [[RICKY MARTIN]]
#
# ✔️ [FINAL CHOOSE] Q128799 - Ricky Martin
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Ricky Martin: {"id": "Q128799", "name": "Mart\u00edn", "surname": "Mart\u00edn", "birthdate": "1971-12-24", "deathdate": null, "nationality": "PR", "artist": "7slfeZO9LsJbWgpkIoXBUJ", "complete_name": "Enrique Mart\u00edn Morales", "entity_name": "Ricky Martin"}
#
#
#
# 🧑‍🎤 [[THE VAMPS]]
#
# ✔️ [FINAL CHOOSE] Q15042553 - The Vamps
#
# 👪 [MEMBERS]
#
# 🗃️ [PEOPLE RETRIEVED]
# Brad Simpson: {"id": "Q27836004", "name": "Simpson", "surname": "Simpson", "birthdate": "1995-07-28", "deathdate": null, "nationality": "GB", "artist": "7gAppWoH7pcYmphCVTXkzs", "complete_name": null, "entity_name": "Brad Simpson"}
# James McVey: {"id": "Q27836012", "name": "McVey", "surname": "McVey", "birthdate": "1994-04-30", "deathdate": null, "nationality": null, "artist": "7gAppWoH7pcYmphCVTXkzs", "complete_name": null, "entity_name": "James McVey"}
# Connor Ball: {"id": "Q27836043", "name": "Ball", "surname": "Ball", "birthdate": "1996-03-15", "deathdate": null, "nationality": null, "artist": "7gAppWoH7pcYmphCVTXkzs", "complete_name": null, "entity_name": "Connor Ball"}
# Tristan Evans: {"id": "Q27839463", "name": "Evans", "surname": "Evans", "birthdate": "1994-08-15", "deathdate": null, "nationality": null, "artist": "7gAppWoH7pcYmphCVTXkzs", "complete_name": null, "entity_name": "Tristan Evans"}
#
#
#
# 🧑‍🎤 [[MATOMA]]
#
# ✔️ [FINAL CHOOSE] Q19845354 - Matoma
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Matoma: {"id": "Q19845354", "name": "Lagergren", "surname": "Lagergren", "birthdate": "1991-05-29", "deathdate": null, "nationality": "NO", "artist": "4YXycRbyyAE0wozTk7QMEq", "complete_name": "Tom Str\u00e6te Lagergren", "entity_name": "Matoma"}
#
#
#
# 🧑‍🎤 [[JONAS BLUE]]
#
# ✔️ [FINAL CHOOSE] Q22246459 - Jonas Blue
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Jonas Blue: {"id": "Q22246459", "name": null, "surname": null, "birthdate": "1989-08-02", "deathdate": null, "nationality": null, "artist": "1HBjj22wzbscIZ9sEb5dyf", "complete_name": "Guy James Robin", "entity_name": "Jonas Blue"}
#
#
#
# 🧑‍🎤 [[RAYE]]
#
# ✔️ [FINAL CHOOSE] Q28071144 - RAYE
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Raye: {"id": "Q28071144", "name": "Keen", "surname": "Keen", "birthdate": "1997-10-24", "deathdate": null, "nationality": "GB", "artist": "5KKpBU5eC2tJDzf0wmlRp2", "complete_name": "Rachel Agatha Keen", "entity_name": "Raye"}
#
#
#
# 🧑‍🎤 [[CHARLIE PUTH]]
#
# ✔️ [FINAL CHOOSE] Q19810390 - Charlie Puth
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Charlie Puth: {"id": "Q19810390", "name": "Puth", "surname": "Puth", "birthdate": "1991-12-02", "deathdate": null, "nationality": "US", "artist": "6VuMaDnrHyPL1p4EHjYLi7", "complete_name": "Charles Otto Puth Jr.", "entity_name": "Charlie Puth"}
#
#
#
# 🧑‍🎤 [[SELENA GOMEZ]]
#
# ✔️ [FINAL CHOOSE] Q83287 - Selena Gomez
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Selena Gomez: {"id": "Q83287", "name": "G\u00f3mez", "surname": "G\u00f3mez", "birthdate": "1992-07-22", "deathdate": null, "nationality": "US", "artist": "0C8ZW7ezQVs4URX5aX7Kqx", "complete_name": "Selena Marie Gomez", "entity_name": "Selena Gomez"}
#
#
#
# 🧑‍🎤 [[AMINÉ]]
#
# ✔️ [FINAL CHOOSE] Q27830860 - Aminé
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Aminé: {"id": "Q27830860", "name": "Daniel", "surname": "Daniel", "birthdate": "1996-04-18", "deathdate": null, "nationality": "US", "artist": "3Gm5F95VdRxW3mqCn8RPBJ", "complete_name": "Adam Amin\u00e9 Daniel", "entity_name": "Amin\u00e9"}
#
#
#
# 🧑‍🎤 [[SAGE THE GEMINI]]
#
# ✔️ [FINAL CHOOSE] Q15080570 - Sage the Gemini
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Sage the Gemini: {"id": "Q15080570", "name": "Woods", "surname": "Woods", "birthdate": "1992-06-20", "deathdate": null, "nationality": "US", "artist": "6d47Z08T4snK50HgTEHo5Z", "complete_name": "Dominic Wynn Woods", "entity_name": "Sage the Gemini"}
#
#
#
# 🧑‍🎤 [[JOHN LEGEND]]
#
# ✔️ [FINAL CHOOSE] Q44857 - John Legend
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# John Legend: {"id": "Q44857", "name": "Stephens", "surname": "Stephens", "birthdate": "1978-12-28", "deathdate": null, "nationality": "US", "artist": "5y2Xq6xcjJb2jVM54GHK3t", "complete_name": "John Roger Stephens", "entity_name": "John Legend"}
#
#
#
# 🧑‍🎤 [[NEVADA]]
#
# 🛑 [NO MATCHES ON MUSICBRAINZ, TRYING TO WIKIDATA]
#
# 🔍 [SEARCH RESULTS]
# - state of the united states of america
# - county seat of washoe county, nevada, united states
# - town in vernon county, missouri, united states
# - county in nevada, united states
# - county in nevada, united states
# - county in nevada, united states
# - county in nevada, united states
# - county in nevada, united states
# - county in california, united states
# - county in nevada, united states
# - county in nevada, united states
# - county in nevada, united states
# - county in nevada, united states
# - town in story county, iowa, united states
# - county in nevada, united states
# - county in nevada, united states
# - county in nevada, united states
# - county in nevada, united states
# - municipality in granada, spain
# - county in nevada, united states
#
# 🛑 [NO MATCHES ON WIKIDATA]
#
#
#
# 🧑‍🎤 [[MARK MORRISON]]
#
# ✔️ [FINAL CHOOSE] Q1364471 - Mark Morrison
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Mark Morrison: {"id": "Q1364471", "name": "Morrison", "surname": "Morrison", "birthdate": "1972-05-03", "deathdate": null, "nationality": "GB", "artist": "6V3F8MZrOKdT9fU686ybE9", "complete_name": null, "entity_name": "Mark Morrison"}
#
#
#
# 🧑‍🎤 [[FETTY WAP]]
#
# ✔️ [FINAL CHOOSE] Q19361511 - Fetty Wap
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Fetty Wap: {"id": "Q19361511", "name": "Maxwell", "surname": "Maxwell", "birthdate": "1991-06-07", "deathdate": null, "nationality": "US", "artist": "6PXS4YHDkKvl1wkIl4V8DL", "complete_name": "Willie Junior Maxwell II", "entity_name": "Fetty Wap"}
#
#
#
# 🧑‍🎤 [[ALAN WALKER]]
#
# ✔️ [FINAL CHOOSE] Q21808729 - Alan Walker
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Alan Walker: {"id": "Q21808729", "name": "Walker", "surname": "Walker", "birthdate": "1997-08-24", "deathdate": null, "nationality": "NO", "artist": "7vk5e3vY1uw9plTHJAMwjN", "complete_name": "Alan Olav Walker", "entity_name": "Alan Walker"}
#
#
#
# 🧑‍🎤 [[ZION & LENNOX]]
#
# ✔️ [FINAL CHOOSE] Q205352 - Zion & Lennox
#
# 👪 [MEMBERS]
#
# 🗃️ [PEOPLE RETRIEVED]
# Zion: {"id": "Q6171416", "name": null, "surname": "", "birthdate": "1981-08-05", "deathdate": null, "nationality": "PR", "artist": "21451j1KhjAiaYKflxBjr1", "complete_name": null, "entity_name": "Zion"}
# Lennox: {"id": "Q5972994", "name": "Pizarro", "surname": "Pizarro", "birthdate": "1980-12-10", "deathdate": null, "nationality": "PR", "artist": "21451j1KhjAiaYKflxBjr1", "complete_name": "Gabriel Enrique Pizarro Pizarro", "entity_name": "Lennox"}
#
#
#
# 🧑‍🎤 [[ZARA LARSSON]]
#
# ✔️ [FINAL CHOOSE] Q4177928 - Zara Larsson
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Zara Maria Larsson: {"id": "Q4177928", "name": "Larsson", "surname": "Larsson", "birthdate": "1997-12-16", "deathdate": null, "nationality": "SE", "artist": "1Xylc3o4UrD53lo9CvFvVg", "complete_name": "Zara Maria Larsson", "entity_name": "Zara Maria Larsson"}
#
#
#
# 🧑‍🎤 [[ALOK]]
#
# ✔️ [FINAL CHOOSE] Q28007321 - Alok
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Alok: {"id": "Q28007321", "name": null, "surname": null, "birthdate": "1991-08-26", "deathdate": null, "nationality": "BR", "artist": "0NGAZxHanS9e0iNHpR8f2W", "complete_name": null, "entity_name": "Alok"}
#
#
#
# 🧑‍🎤 [[BRUNO MARTINI]]
#
# ✔️ [FINAL CHOOSE] Q30939186 - Bruno Martini
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Bruno Martini: {"id": "Q30939186", "name": "Martini", "surname": "Martini", "birthdate": "1992-10-01", "deathdate": null, "nationality": "BR", "artist": "5veVxxPm1vzgi6pO2iVA8L", "complete_name": null, "entity_name": "Bruno Martini"}
#
#
#
# 🧑‍🎤 [[ZEEBA]]
#
# ✔️ [FINAL CHOOSE] Q30938233 - Zeeba
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Zeeba: {"id": "Q30938233", "name": null, "surname": null, "birthdate": "1993-01-26", "deathdate": null, "nationality": null, "artist": "7qPLO2XOUaRrRxkvLZ3AEK", "complete_name": null, "entity_name": "Zeeba"}
#
#
#
# 🧑‍🎤 [[ROBIN SCHULZ]]
#
# ✔️ [FINAL CHOOSE] Q16231940 - Robin Schulz
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Robin Schulz: {"id": "Q16231940", "name": "Schulz", "surname": "Schulz", "birthdate": "1987-04-28", "deathdate": null, "nationality": "DE", "artist": "3t5xRXzsuZmMDkQzgOX35S", "complete_name": "Robin Alexander Schulz", "entity_name": "Robin Schulz"}
#
#
#
# 🧑‍🎤 [[DAVID GUETTA]]
#
# ✔️ [FINAL CHOOSE] Q8298 - David Guetta
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# David Guetta: {"id": "Q8298", "name": "Guetta", "surname": "Guetta", "birthdate": "1967-11-07", "deathdate": null, "nationality": "FR", "artist": "1Cs0zKBU1kc0i8ypK3B9ai", "complete_name": "Pierre David Guetta", "entity_name": "David Guetta"}
#
#
#
# 🧑‍🎤 [[CHEAT CODES]]
#
# ✔️ [FINAL CHOOSE] Q23978754 - Cheat Codes
#
# 🛑 [NO INFORMATION TO RETRIEVE, TRYING WITH MUSICBRAINZ DATA]
#
# 🗃️ [PEOPLE RETRIEVED]
# Dahl: {"id": "00fa66a8-f3b6-4b58-843a-8fcd0d04ece2", "name": "Dahl", "surname": "Dahl", "birthdate": null, "deathdate": null, "nationality": "US", "artist": "7DMveApC7UnC2NPfPvlHSU", "complete_name": "Trevor Edmund Dahl", "entity_name": "Dahl"}
# Kevin Ford: {"id": "8bab537c-6d29-4673-95e2-90606eeb1ce3", "name": "Ford", "surname": "Ford", "birthdate": null, "deathdate": null, "nationality": null, "artist": "7DMveApC7UnC2NPfPvlHSU", "complete_name": null, "entity_name": "Kevin Ford"}
# Matthew Russell: {"id": "d70728b9-75a4-4f42-bd4b-af28b70ddeaa", "name": "Russell", "surname": "Russell", "birthdate": null, "deathdate": null, "nationality": null, "artist": "7DMveApC7UnC2NPfPvlHSU", "complete_name": null, "entity_name": "Matthew Russell"}
#
#
#
# 🧑‍🎤 [[BIG SEAN]]
#
# ✔️ [FINAL CHOOSE] Q367634 - Big Sean
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Big Sean: {"id": "Q367634", "name": "Anderson", "surname": "Anderson", "birthdate": "1988-03-25", "deathdate": null, "nationality": "US", "artist": "0c173mlxpT3dSFRgMO8XPh", "complete_name": "Sean Michael Leonard Anderson", "entity_name": "Big Sean"}
#
#
#
# 🧑‍🎤 [[DNCE]]
#
# ✔️ [FINAL CHOOSE] Q21648421 - DNCE
#
# 👪 [MEMBERS]
#
# 🗃️ [PEOPLE RETRIEVED]
# Joe Jonas: {"id": "Q191088", "name": "Jonas", "surname": "Jonas", "birthdate": "1989-08-15", "deathdate": null, "nationality": "US", "artist": "6T5tfhQCknKG4UnH90qGnz", "complete_name": "Joseph Adam Jonas", "entity_name": "Joe Jonas"}
# Jack Lawless: {"id": "Q6113606", "name": "Lawless", "surname": "Lawless", "birthdate": "1987-09-20", "deathdate": null, "nationality": "US", "artist": "6T5tfhQCknKG4UnH90qGnz", "complete_name": null, "entity_name": "Jack Lawless"}
# JinJoo Lee: {"id": "Q24287375", "name": "Lee", "surname": "Lee", "birthdate": "1987-11-15", "deathdate": null, "nationality": "KR", "artist": "6T5tfhQCknKG4UnH90qGnz", "complete_name": null, "entity_name": "JinJoo Lee"}
# Cole Whittle: {"id": "Q97570445", "name": "Whittle", "surname": "Whittle", "birthdate": "1982-02-22", "deathdate": null, "nationality": "US", "artist": "6T5tfhQCknKG4UnH90qGnz", "complete_name": null, "entity_name": "Cole Whittle"}
#
#
#
# 🧑‍🎤 [[CARLOS VIVES]]
#
# ✔️ [FINAL CHOOSE] Q965888 - Carlos Vives
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Carlos Vives: {"id": "Q965888", "name": "Vives", "surname": "Vives", "birthdate": "1960-08-07", "deathdate": null, "nationality": "CO", "artist": "4vhNDa5ycK0ST968ek7kRr", "complete_name": "Carlos Alberto Vives Restrepo", "entity_name": "Carlos Vives"}
#
#
#
# 🧑‍🎤 [[JP COOPER]]
#
# ✔️ [FINAL CHOOSE] Q27807517 - JP Cooper
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# JP Cooper: {"id": "Q27807517", "name": "Cooper", "surname": "Cooper", "birthdate": "1983-11-01", "deathdate": null, "nationality": "GB", "artist": "4kYGAK2zu9EAomwj3hXkXy", "complete_name": "John Paul Cooper", "entity_name": "JP Cooper"}
#
#
#
# 🧑‍🎤 [[DESIIGNER]]
#
# ✔️ [FINAL CHOOSE] Q23091498 - Desiigner
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Desiigner: {"id": "Q23091498", "name": "Royel Selby III", "surname": "Royel Selby III", "birthdate": "1997-05-03", "deathdate": null, "nationality": "US", "artist": "7pFeBzX627ff0VnN6bxPR4", "complete_name": "Sidney Royel Selby III", "entity_name": "Desiigner"}
#
#
#
# 🧑‍🎤 [[NEIKED]]
#
# ✔️ [FINAL CHOOSE] Q26703294 - NEIKED
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Neiked: {"id": "Q26703294", "name": "R\u00e5dstr\u00f6m", "surname": "R\u00e5dstr\u00f6m", "birthdate": "1991-12-28", "deathdate": null, "nationality": "SE", "artist": "5H6xmHXjsq98NLbEjuE29f", "complete_name": "Victor R\u00e5dstr\u00f6m", "entity_name": "Neiked"}
#
#
#
# 🧑‍🎤 [[DYO]]
#
# 🛑 [NO MATCHES ON MUSICBRAINZ, TRYING TO WIKIDATA]
#
# 🔍 [SEARCH RESULTS]
# - commune in saône-et-loire, france
# - wikimedia disambiguation page
# -
# - watercourse in the ivory coast
# - watercourse in ivory coast
# --> english r&amp;b singer
# -
# -
# -
# - album by mando
# -
# -
# - ph.d. university college london 2009
# - river in cyprus
# - community in nicosia district, republic of cyprus
# - researcher orcid id = 0000-0003-4747-0870
# - television series
# - human settlement in greece
# -
# - church located in saône-et-loire, in france
#
# ✔️ [FINAL CHOOSE] Q12573027 - English R&amp;B singer
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Dyo: {"id": "Q12573027", "name": "Olatunji", "surname": "Olatunji", "birthdate": "1992-03-04", "deathdate": null, "nationality": "GB", "artist": "4H1PNuHElBLVok0lnYMrRb", "complete_name": "Oladayo Olatunji", "entity_name": "Dyo"}
#
#
#
# 🧑‍🎤 [[J. COLE]]
#
# ✔️ [FINAL CHOOSE] Q204018 - J. Cole
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# J Cole: {"id": "Q204018", "name": "Cole", "surname": "Cole", "birthdate": "1985-01-28", "deathdate": null, "nationality": "US", "artist": "6l3HvQ5sa6mXTsMTB19rO5", "complete_name": "Jermaine Lamarr Cole", "entity_name": "J Cole"}
#
#
#
# 🧑‍🎤 [[DADDY YANKEE]]
#
# ✔️ [FINAL CHOOSE] Q272591 - Daddy Yankee
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Daddy Yankee: {"id": "Q272591", "name": "Ayala", "surname": "Ayala", "birthdate": "1977-02-03", "deathdate": null, "nationality": "PR", "artist": "4VMYDCV2IEDYJArk749S6m", "complete_name": "Ram\u00f3n Luis Ayala Rodr\u00edguez", "entity_name": "Daddy Yankee"}
#
#
#
# 🧑‍🎤 [[NYLA]]
#
# ✔️ [FINAL CHOOSE] Q22279445 - Nyla
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Nyla: {"id": "Q22279445", "name": null, "surname": null, "birthdate": "1983-11-27", "deathdate": null, "nationality": "JM", "artist": "4VZY0nxYMSNotbS7WjNVQy", "complete_name": null, "entity_name": "Nyla"}
#
#
#
# 🧑‍🎤 [[FUSE ODG]]
#
# ✔️ [FINAL CHOOSE] Q5509984 - Fuse ODG
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Fuse ODG: {"id": "Q5509984", "name": "ODG", "surname": "ODG", "birthdate": "1988-12-02", "deathdate": null, "nationality": "GB", "artist": "374sWpAJsbZckf98df2jJJ", "complete_name": null, "entity_name": "Fuse ODG"}
#
#
#
# 🧑‍🎤 [[SEBASTIAN YATRA]]
#
# ✔️ [FINAL CHOOSE] Q17478270 - Sebastián Yatra
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Sebastián Yatra: {"id": "Q17478270", "name": "Obando", "surname": "Obando", "birthdate": "1994-10-15", "deathdate": null, "nationality": "CO", "artist": "07YUOmWljBTXwIseAUd9TW", "complete_name": "Sebastian Obando Giraldo", "entity_name": "Sebasti\u00e1n Yatra"}
#
#
#
# 🧑‍🎤 [[21 SAVAGE]]
#
# ✔️ [FINAL CHOOSE] Q25095399 - 21 Savage
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# 21 Savage: {"id": "Q25095399", "name": "Abraham Joseph", "surname": "Abraham Joseph", "birthdate": "1992-10-22", "deathdate": null, "nationality": "GB", "artist": "1URnnhqYAYcrqrcwql10ft", "complete_name": "Sh\u00e9yaa Bin Abraham-Joseph", "entity_name": "21 Savage"}
#
#
#
# 🧑‍🎤 [[METRO BOOMIN]]
#
# ✔️ [FINAL CHOOSE] Q16235273 - Metro Boomin
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Metro Boomin: {"id": "Q16235273", "name": "Wayne", "surname": "Wayne", "birthdate": "1993-09-16", "deathdate": null, "nationality": "US", "artist": "0iEtIxbK0KxaSlF7G42ZOp", "complete_name": "Leland Tyler Wayne", "entity_name": "Metro Boomin"}
#
#
#
# 🧑‍🎤 [[FUTURE]]
#
# ✔️ [FINAL CHOOSE] Q3445057 - Future
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Future: {"id": "Q3445057", "name": "Wilburn", "surname": "Wilburn", "birthdate": "1983-11-20", "deathdate": null, "nationality": "US", "artist": "1RyvyyTE3xzB2ZywiAwp0i", "complete_name": "Nayvadius DeMun Wilburn", "entity_name": "Future"}
#
#
#
# 🧑‍🎤 [[ADELE]]
#
# ✔️ [FINAL CHOOSE] Q23215 - Adele
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Adele: {"id": "Q23215", "name": "Adkins", "surname": "Adkins", "birthdate": "1988-05-05", "deathdate": null, "nationality": "GB", "artist": "4dpARuHxo51G3z768sgnrY", "complete_name": "Adele Laurie Blue Adkins", "entity_name": "Adele"}
#
#
#
# 🧑‍🎤 [[ZAY HILFIGERRR]]
#
# 🛑 [NO MATCHES ON MUSICBRAINZ, TRYING TO WIKIDATA]
#
# 🔍 [SEARCH RESULTS]
# -
# - <span class="searchmatch">zay</span> <span class="searchmatch">hilfigerrr</span> and zayion mccall song
# --> american hip hop duo
#
# ✔️ [FINAL CHOOSE] Q48739636 - American hip hop duo
#
# 👪 [MEMBERS]
#
# 🗃️ [PEOPLE RETRIEVED]
# Zay Hilfigerrr: {"id": "Q55859289", "name": "Hilfigerrr", "surname": "Hilfigerrr", "birthdate": null, "deathdate": null, "nationality": null, "artist": "7nKeLE1toRtW4M279iS26h", "complete_name": null, "entity_name": "Zay Hilfigerrr"}
# Zayion McCall: {"id": "Q55859293", "name": "McCall", "surname": "McCall", "birthdate": null, "deathdate": null, "nationality": null, "artist": "7nKeLE1toRtW4M279iS26h", "complete_name": null, "entity_name": "Zayion McCall"}
#
#
#
# 🧑‍🎤 [[ZAYION MCCALL]]
#
# 🛑 [NO MATCHES ON MUSICBRAINZ, TRYING TO WIKIDATA]
#
# 🔍 [SEARCH RESULTS]
# -
# - zay hilfigerrr and <span class="searchmatch">zayion</span> <span class="searchmatch">mccall</span> song
# --> american hip hop duo
#
# ✔️ [FINAL CHOOSE] Q48739636 - American hip hop duo
#
# 👪 [MEMBERS]
#
# 🗃️ [PEOPLE RETRIEVED]
# Zay Hilfigerrr: {"id": "Q55859289", "name": "Hilfigerrr", "surname": "Hilfigerrr", "birthdate": null, "deathdate": null, "nationality": null, "artist": "5AsWcQXw4RJFRWBbwa0ti0", "complete_name": null, "entity_name": "Zay Hilfigerrr"}
# Zayion McCall: {"id": "Q55859293", "name": "McCall", "surname": "McCall", "birthdate": null, "deathdate": null, "nationality": null, "artist": "5AsWcQXw4RJFRWBbwa0ti0", "complete_name": null, "entity_name": "Zayion McCall"}
#
#
#
# 🧑‍🎤 [[ENRIQUE IGLESIAS]]
#
# ✔️ [FINAL CHOOSE] Q47122 - Enrique Iglesias
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Enrique Iglesias: {"id": "Q47122", "name": "Iglesias", "surname": "Iglesias", "birthdate": "1975-05-08", "deathdate": null, "nationality": "ES", "artist": "7qG3b048QCHVRO5Pv1T5lw", "complete_name": "Enrique Miguel Iglesias Preysler", "entity_name": "Enrique Iglesias"}
#
#
#
# 🧑‍🎤 [[WISIN]]
#
# ✔️ [FINAL CHOOSE] Q6168030 - Wisin
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Wisin: {"id": "Q6168030", "name": "Morera Luna", "surname": "Morera Luna", "birthdate": "1978-12-19", "deathdate": null, "nationality": "PR", "artist": "3E6xrwgnVfYCrCs0ePERDz", "complete_name": "Juan Luis Morera Luna", "entity_name": "Wisin"}
#
#
#
# 🧑‍🎤 [[COLDPLAY]]
#
# ✔️ [FINAL CHOOSE] Q45188 - Coldplay
#
# 👪 [MEMBERS]
#
# 🗃️ [PEOPLE RETRIEVED]
# Chris Martin: {"id": "Q712860", "name": "Martin", "surname": "Martin", "birthdate": "1977-03-02", "deathdate": null, "nationality": "GB", "artist": "4gzpq5DPGxSnKTe4SA8HAU", "complete_name": null, "entity_name": "Chris Martin"}
# Jonny Buckland: {"id": "Q822029", "name": "Buckland", "surname": "Buckland", "birthdate": "1977-09-11", "deathdate": null, "nationality": "GB", "artist": "4gzpq5DPGxSnKTe4SA8HAU", "complete_name": "Jonathan Mark Buckland", "entity_name": "Jonny Buckland"}
# ...
#
# 🔍 [SEARCH RESULTS]
# -
# - 2019 album by natti natasha
#
# 🛑 [NO MATCHES ON WIKIDATA]
#
#
#
# 🧑‍🎤 [[GEPE]]
#
# ✔️ [FINAL CHOOSE] Q5548652 - Gepe
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Gepe: {"id": "Q5548652", "name": "Riveros", "surname": "Riveros", "birthdate": "1981-09-28", "deathdate": null, "nationality": "CL", "artist": "1fHGzTSloWCtrlKfbLNVhM", "complete_name": "Daniel Alejandro Riveros Sep\u00falveda", "entity_name": "Gepe"}
#
#
#
# 🧑‍🎤 [[JUGGLERZ]]
#
# 🛑 [NO MATCHES ON MUSICBRAINZ, TRYING TO WIKIDATA]
#
# 🔍 [SEARCH RESULTS]
# -
# - 2017 single by bausa
#
# 🛑 [NO MATCHES ON WIKIDATA]
#
#
#
# 🧑‍🎤 [[CHATLE]]
#
# 🛑 [NO MATCHES ON MUSICBRAINZ, TRYING TO WIKIDATA]
#
# 🔍 [SEARCH RESULTS]
# - researcher
# - scientific article published in july 2004
#
# 🛑 [NO MATCHES ON WIKIDATA]
#
#
#
# 🧑‍🎤 [[MAIKEL DELACALLE]]
#
# 🛑 [NO MATCHES ON MUSICBRAINZ, TRYING TO WIKIDATA]
#
# 🔍 [SEARCH RESULTS]
# --> spanish singer
#
# ✔️ [FINAL CHOOSE] Q62938561 - Spanish singer
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Maikel Delacalle: {"id": "Q62938561", "name": "Delacalle", "surname": "Delacalle", "birthdate": "1994-09-16", "deathdate": null, "nationality": "ES", "artist": "2t7vyRN71qtQT18frElAnV", "complete_name": null, "entity_name": "Maikel Delacalle"}
#
#
#
# 🧑‍🎤 [[BENJAMIN]]
#
# ✔️ [FINAL CHOOSE] Q150767 - Benjamin Britten
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Benjamin Britten: {"id": "Q150767", "name": "Britten", "surname": "Britten", "birthdate": "1913-11-22", "deathdate": "1976-12-04", "nationality": "GB", "artist": "5FgAhHocNrSCn7Ox87uyef", "complete_name": "Edward Benjamin Britten", "entity_name": "Benjamin Britten"}
#
#
#
# 🧑‍🎤 [[KYMPPILINJA]]
#
# 🛑 [NO MATCHES ON MUSICBRAINZ, TRYING TO WIKIDATA]
#
# 🔍 [SEARCH RESULTS]
# --> finnish band
# - album by <span class="searchmatch">kymppilinja</span>
# - album by <span class="searchmatch">kymppilinja</span>
# - wikimedia category
#
# ✔️ [FINAL CHOOSE] Q10314887 - Finnish band
#
# 🛑 [NO INFORMATION TO RETRIEVE, TRYING WITH MUSICBRAINZ DATA]
# 🛑 [NO MUSICBRAINZ DATA]
#
# 🗃️ [PEOPLE RETRIEVED]
#
#
#
# 🧑‍🎤 [[COSTEE]]
#
# 🛑 [NO MATCHES ON MUSICBRAINZ, TRYING TO WIKIDATA]
#
# 🔍 [SEARCH RESULTS]
# --> finnish singer-songwriter
# - wikimedia artist discography
# - 2020 album by <span class="searchmatch">costee</span>
# - 2019 debut album by <span class="searchmatch">costee</span>
# - wikimedia list of songs by performer
# - 2020 extended play by <span class="searchmatch">costee</span> and tippa
# - article
#
# ✔️ [FINAL CHOOSE] Q57943867 - Finnish singer-songwriter
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Costee: {"id": "Q57943867", "name": "Tiainen", "surname": "Tiainen", "birthdate": null, "deathdate": null, "nationality": "FI", "artist": "3I4GcOB25cSJHa9d7Bsgji", "complete_name": null, "entity_name": "Costee"}
#
#
#
# 🧑‍🎤 [[OG EASTBULL]]
#
# 🛑 [NO MATCHES ON MUSICBRAINZ, TRYING TO WIKIDATA]
#
# 🔍 [SEARCH RESULTS]
# -
#
# 🛑 [NO MATCHES ON WIKIDATA]
#
#
#
# 🧑‍🎤 [[DOGSLIFE]]
#
# 🛑 [NO MATCHES ON MUSICBRAINZ, TRYING TO WIKIDATA]
#
# 🔍 [SEARCH RESULTS]
# - article
# - scientific article
# - scientific article published on 27 june 2016
# - scientific article
# - scientific article
# - book by ann m. martin
#
# 🛑 [NO MATCHES ON WIKIDATA]
#
#
#
# 🧑‍🎤 [[MAGO DEL BLOCCO]]
#
# ✔️ [FINAL CHOOSE] Q4927089 - Blocco mentale
#
# 🛑 [NO INFORMATION TO RETRIEVE, TRYING WITH MUSICBRAINZ DATA]
#
# 🗃️ [PEOPLE RETRIEVED]
#
#
#
# 🧑‍🎤 [[EL DE LA GUITARRA]]
#
# 🛑 [NO MATCHES ON MUSICBRAINZ, TRYING TO WIKIDATA]
#
# 🔍 [SEARCH RESULTS]
# - scholarly article
# - painting by francisco <span class="searchmatch">de</span> goya
# - painting by francisco <span class="searchmatch">de</span> goya
# - single
# - human settlement in mexico
# -
# - painting by juan gris (josé victoriano gonzález pérez)
# - painting by theo van rysselberghe (<span class="searchmatch">el</span> prado p004633)
# --> australian pop-rock band
# --> singer-songwriter
# - species of fish
# - form of dance and movement
# - painting by ramón bayeu y subías
# --> german musician
#
# ✔️ [FINAL CHOOSE] Q3775600 - singer-songwriter
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Enrique Delgado: {"id": "Q3775600", "name": "Delgado", "surname": "Delgado", "birthdate": "1939-03-14", "deathdate": "1996-03-21", "nationality": "PE", "artist": "0LIyZkH7LLbsA9T4YwUnEk", "complete_name": null, "entity_name": "Enrique Delgado"}
#
#
#
# 🧑‍🎤 [[I BELONG TO THE ZOO]]
#
# 🛑 [NO MATCHES ON MUSICBRAINZ, TRYING TO WIKIDATA]
#
# 🛑 [NO MATCHES ON WIKIDATA]
#
#
#
# 🧑‍🎤 [[KAMIKAZEE]]
#
# ✔️ [FINAL CHOOSE] Q3812690 - Kamikazee
#
# 🛑 [NO INFORMATION TO RETRIEVE, TRYING WITH MUSICBRAINZ DATA]
#
# 🗃️ [PEOPLE RETRIEVED]
# Jay Contreras: {"id": "3bed113e-759b-455a-b781-21b8381cfb09", "name": "Contreras", "surname": "Contreras", "birthdate": null, "deathdate": null, "nationality": "PH", "artist": "4GBFKKuwmZUnAJt6nBal7A", "complete_name": null, "entity_name": "Jay Contreras"}
# Jose Ma. Luis Linao: {"id": "68608896-bb83-4df7-bc18-cb99c9d3c7cd", "name": "Ma. Luis Linao", "surname": "Ma. Luis Linao", "birthdate": null, "deathdate": null, "nationality": "PH", "artist": "4GBFKKuwmZUnAJt6nBal7A", "complete_name": null, "entity_name": "Jose Ma. Luis Linao"}
#
#
#
# 🧑‍🎤 [[ORANGE & LEMONS]]
#
# 🛑 [NO MATCHES ON MUSICBRAINZ, TRYING TO WIKIDATA]
#
# 🔍 [SEARCH RESULTS]
# -
# --> filipino pop rock band
# - album by xtc
# --> japanese music group
# - 2002 single by oranges &amp; <span class="searchmatch">lemons</span>
# - 1923 film by george jeske
# - rose cultivar
# - painting by pierre-auguste renoir
# - genus of fruit-bearing plants (source of fruit such as <span class="searchmatch">lemons</span> and oranges)
# - folk song
# - scientific article published on 01 september 1973
# - wikimedia disambiguation page
# -
# - cocktail traditionally made with cognac, <span class="searchmatch">orange</span> liqueur and <span class="searchmatch">lemon</span>
# - scientific article published in march 1977
# - painting by joris van son
# - scientific article published in january 2010
# - scientific article published in april 2003
# - <span class="searchmatch">lemon</span> or <span class="searchmatch">orange</span>-flavoured drink popular in india
# -
#
# ✔️ [FINAL CHOOSE] Q11237965 - Japanese music group
#
# 🛑 [NO INFORMATION TO RETRIEVE, TRYING WITH MUSICBRAINZ DATA]
# 🛑 [NO MUSICBRAINZ DATA]
#
# 🗃️ [PEOPLE RETRIEVED]
#
#
#
# 🧑‍🎤 [[PAWEŁ DOMAGAŁA]]
#
# 🛑 [NO MATCHES ON MUSICBRAINZ, TRYING TO WIKIDATA]
#
# 🔍 [SEARCH RESULTS]
# --> polish actor and singer
# - album by <span class="searchmatch">paweł</span> <span class="searchmatch">domagała</span>
# - album by <span class="searchmatch">paweł</span> <span class="searchmatch">domagała</span>
# -
# - scientific article published on 24 september 2020
# - scientific article published on 26 june 2019
# - scientific article published on 29 september 2019
# - scientific article published on 28 august 2019
# - scientific article
# - scientific article published in plos one
# - article
# - scientific article published in september 2013
# - scientific article published on 20 april 2012
# - scientific article published on 01 september 2020
# - scientific article published on 01 september 2020
# - scientific article published on 13 october 2019
# - scientific article
# - scientific article published on 16 september 2013
# - scientific article published on 2 october 2013
# - scientific article published on 01 january 2018
#
# ✔️ [FINAL CHOOSE] Q17703451 - Polish actor and singer
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Paweł Domagała: {"id": "Q17703451", "name": "Domaga\u0142a", "surname": "Domaga\u0142a", "birthdate": "1984-01-19", "deathdate": null, "nationality": null, "artist": "0Gk98lHv6LlqbWPwdMiga2", "complete_name": null, "entity_name": "Pawe\u0142 Domaga\u0142a"}
#
#
#
# 🧑‍🎤 [[SARIUS]]
#
# 🛑 [NO MATCHES ON MUSICBRAINZ, TRYING TO WIKIDATA]
#
# 🔍 [SEARCH RESULTS]
# -
# - ancient roman nomen
# - families from ancient rome who shared <span class="searchmatch">sarius</span> nomen
# - 2017 album by <span class="searchmatch">sarius</span>
# - album by <span class="searchmatch">sarius</span>
# - river in italy
# - polish magnate, statesman and military commander (1542-1605)
# -
# -
# -
# - lake in lithuania
# -
# - reservoir in lithuania
# -
# -
# -
#
# 🛑 [NO MATCHES ON WIKIDATA]
#
#
#
# 🧑‍🎤 [[MC ZUKA]]
#
# 🛑 [NO MATCHES ON MUSICBRAINZ, TRYING TO WIKIDATA]
#
# 🛑 [NO MATCHES ON WIKIDATA]
#
#
#
# 🧑‍🎤 [[DJ DADDA]]
#
# 🛑 [NO MATCHES ON MUSICBRAINZ, TRYING TO WIKIDATA]
#
# 🔍 [SEARCH RESULTS]
# - mauritanian politician (1924-2003)
#
# 🛑 [NO MATCHES ON WIKIDATA]
#
#
#
# 🧑‍🎤 [[IMENELLA]]
#
# 🛑 [NO MATCHES ON MUSICBRAINZ, TRYING TO WIKIDATA]
#
# 🔍 [SEARCH RESULTS]
# --> swedish rapper
#
# ✔️ [FINAL CHOOSE] Q68595431 - Swedish rapper
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Imenella: {"id": "Q68595431", "name": "Mohamed", "surname": "Mohamed", "birthdate": "1988", "deathdate": null, "nationality": "SE", "artist": "6IuS73qKuYfrYqA5g5iq0h", "complete_name": null, "entity_name": "Imenella"}
#
#
#
# 🧑‍🎤 [[KORAY AVCI]]
#
# 🛑 [NO MATCHES ON MUSICBRAINZ, TRYING TO WIKIDATA]
#
# 🔍 [SEARCH RESULTS]
# - turkish footballer
# --> musician
# -
# - wikimedia disambiguation page
# - album by <span class="searchmatch">koray</span> <span class="searchmatch">avcı</span>
# - album by <span class="searchmatch">koray</span> <span class="searchmatch">avcı</span>
# - album by koray<span class="searchmatch"> avcı</span>
# - scientific article published on 01 october 2018
# - wikimedia category
# - wikimedia category
# - scientific article
# - scientific article
#
# ✔️ [FINAL CHOOSE] Q25478741 - musician
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Koray Avcı: {"id": "Q25478741", "name": "Avc\u0131", "surname": "Avc\u0131", "birthdate": "1984-01-01", "deathdate": null, "nationality": "TR", "artist": "3sV7ijrP5xMHgWRlOnPTCi", "complete_name": null, "entity_name": "Koray Avc\u0131"}
#
#
#
# 🧑‍🎤 [[DANIEL CHAN]]
#
# ✔️ [FINAL CHOOSE] Q713937 - 陳曉東
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Daniel Chan: {"id": "Q713937", "name": "Chen", "surname": "Chen", "birthdate": "1975-09-03", "deathdate": null, "nationality": "CN", "artist": "5QpiOYuxf2oqst8hILxnHM", "complete_name": null, "entity_name": "Daniel Chan"}
#
#
#
# 🧑‍🎤 [[HINS CHEUNG]]
#
# ✔️ [FINAL CHOOSE] Q709800 - 張敬軒
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Hins Cheung: {"id": "Q709800", "name": "Zhang", "surname": "Zhang", "birthdate": "1981-02-01", "deathdate": null, "nationality": "HK", "artist": "2MVfNjocvNrE03cQuxpsWK", "complete_name": null, "entity_name": "Hins Cheung"}
#
#
#
# 🧑‍🎤 [[RAE XIE]]
#
# 🛑 [NO MATCHES ON MUSICBRAINZ, TRYING TO WIKIDATA]
#
# 🔍 [SEARCH RESULTS]
# - scientific article published on 28 november 2000
# - scientific article published on 7 july 2006
# - scientific article published on 30 april 2020
# - scientific article
# -
# -
# - scientific article published in march 2011
# -
# - scientific article
# - scientific article published on 17 december 2018
# - scientific article published in journal of biological chemistry
# - scientific article published on 01 september 2018
# - scientific article (publication date:  2002)
# -
# - scientific article
# - scientific article published on 28 august 2019
# - scientific article
# - scientific article published on 27 may 2019
# - scientific article published on 21 august 2020
# - scientific article published on 3 august 2020
#
# 🛑 [NO MATCHES ON WIKIDATA]
#
#
#
# 🧑‍🎤 [[JESSIE REYEZ]]
#
# ✔️ [FINAL CHOOSE] Q29898660 - Jessie Reyez
#
# 👨 [SINGLE ARTIST]
#
# 🗃️ [PEOPLE RETRIEVED]
# Jessie Reyez: {"id": "Q29898660", "name": "Reyez", "surname": "Reyez", "birthdate": "1991-06-12", "deathdate": null, "nationality": "CA", "artist": "3KedxarmBCyFBevnqQHy3P", "complete_name": "Jessica Reyez", "entity_name": "Jessie Reyez"}
#
#
#
# 🧑‍🎤 [[MISSY ELLIOTT]]
#
# ✔️ [FINAL CHOOSE] Q155079 - Missy Elliott
#
# 👨 [SINGLE ARTIST]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_27560/4214227068.py in <module>
#      61             print("\n👨 [SINGLE ARTIST]")
#      62             # Get the information from WikiData
# ---> 63             artistInformation = getArtistInformation(entityClaims)
#      64             # And set other additional information like the artist name, the entity title and the WikiData ID
#      65             artistInformation["artistID"] = artistID
#
# ~\AppData\Local\Temp/ipykernel_27560/2586065753.py in getArtistInformation(entityClaims)
#      23             elif wdDataInformation["type"] == "externalArrayString":
#      24                 for currentEntityInformation in currentInformation:
# ---> 25                     entityToAppend = getEntityTitle(wdGetEntity(currentEntityInformation["id"]))
#      26
#      27                     if realValue is None and not entityToAppend is None:
#
# ~\AppData\Local\Temp/ipykernel_27560/3608800984.py in wdGetEntity(entityID)
#      14 def wdGetEntity(entityID):
#      15     # Format the request
# ---> 16     queryApiRequest = requests.get(
#      17         "https://www.wikidata.org/w/api.php?action=wbgetentities&ids={eID}&format=json".format(eID=entityID))
#      18
#
# C:\Python39\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# C:\Python39\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# C:\Python39\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# C:\Python39\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# C:\Python39\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# C:\Python39\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# C:\Python39\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380         # Trigger any extra validation we need to do.
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#     384             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# C:\Python39\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#    1008         # Force connect early to allow us to validate the connection.
#    1009         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1010             conn.connect()
#    1011
#    1012         if not conn.is_verified:
#
# C:\Python39\lib\site-packages\urllib3\connection.py in connect(self)
#     351     def connect(self):
#     352         # Add certificate verification
# --> 353         conn = self._new_conn()
#     354         hostname = self.host
#     355         tls_in_tls = False
#
# C:\Python39\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     167
#     168         try:
# --> 169             conn = connection.create_connection(
#     170                 (self._dns_host, self.port), self.timeout, **extra_kw
#     171             )
#
# C:\Python39\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      84             if source_address:
#      85                 sock.bind(source_address)
# ---> 86             sock.connect(sa)
#      87             return sock
#      88
#
# KeyboardInterrupt:

# %%
# Save datasets to file
peopleDF.to_csv(peoplePath)
